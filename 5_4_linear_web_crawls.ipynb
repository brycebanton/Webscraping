# %% [markdown]
# ## Linear Web Crawling
#
# * A **linear web crawl** involves pulling info from a list of similar pages
#     * Multiple pages of web reviews
#     * Multiple days/week/years of music on the current
#     * Multiple pages of reviews for a movie

# %% [markdown]
# ## Workflow for a Linear Crawl
#
# * Make a function that processes a single page
# * Make a list of urls
# * Apply the function to the list of urls.

# %% [markdown]
# ## Exploiting url patterns
#
# * We can make a list of all pages by inspecting and exploiting url patterns.
# * Examples:
#     * The date and hour in
#         * `http://www.thecurrent.org/playlist/2014-01-01/01`
#     * The `&start=30` in
#         * `https://www.yelp.com/search?find_desc=Restaurants&find_loc=La+Crosse,+WI&start=30`

# %% [markdown]
# ## Formating Python strings.
#
# * Mark insertion points with `{0}`, `{1}`, etc.
# * Use the `format` method to insert item.

# %%
base_str = "Hello {0}! How's your {1} going?"
base_str.format("Todd", "Monday")
# Out:
# "Hello Todd! How's your Monday going?"

# %%
base_str.format("Chris", "Wednesday")
# Out:
# "Hello Chris! How's your Wednesday going?"

# %% [markdown]
# ## Formating strings in a list comprehension
#
# You can use a list comprehension to format a whole list of strings.

# %%
base_str2 = "Hello {0}!"
[base_str2.format(name) for name in ["Todd", "Chris", "Brant"]]
# Out:
# ['Hello Todd!', 'Hello Chris!', 'Hello Brant!']

# %% [markdown]
# ## Example - Yelp
#
# In a previous lab, we scraped Yelp for a lunch location in La Crosse, WI.  Here is the resulting function.

# %%
def get_page_info(soup):
    indexes = [tag for tag in soup.find_all('span', class_="indexed-biz-name")]
    info_blocks = [tag.find_parent('div', 'biz-listing-large') for tag in indexes]
    names = [tag.find('a', 'biz-name').span.get_text() for tag in info_blocks]
    ratings = [tag.find('div', 'i-stars').img['alt'].split(' ')[0] for tag in info_blocks]
    addresses = [tag.find('address').get_text().strip() for tag in info_blocks if tag.find('address') is not None]
    review_count = [tag.find('span', 'review-count').next.strip().split(" ")[0] for tag in info_blocks]
    get_and_combine_categories = lambda cat_list: ";".join([tag.next for tag in cat_list.find_all('a')])
    cat_lists = [tag.find('span', 'category-str-list') for tag in info_blocks]
    categories = [get_and_combine_categories(tag) for tag in cat_lists]
    return [row for row in zip(names, ratings, addresses, review_count, categories)]

# %% [markdown]
# ## <font color='red'> Exercise 5 </font>
#
# **Tasks**
# 1. Get the addresses for the first two pages of search output.
# 2. Identify the part of the address related to the page.
#     * Look for `&start=30`
# 3. Build a `base_string`
#     * Replace `&start=30` with `&start={0}`
#     * Verify that `base_string.format(30)` replaces the `{0}` with `30`
# 3. Build a list of urls for all of the search results.
#     * Note that there are 8 pages listed for La Crosse.  We want 8 links.
#     * Use `range` and a list comprehension to replace `{0}` with `0`, `30`, ...

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Step 1 - Get a soup for each url

# %%
base_str = "https://www.yelp.com/search?find_desc=Restaurants&find_loc=La+Crosse,+WI&start={0}"
urls = [base_str.format(i) for i in range(0, 8*30, 30)]
s = requests.Session()

def get_soup(url):
    print("Loading {}".format(url))
    r = s.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    return soup

soups = [get_soup(url) for url in urls]
# Out:
# Loading https://www.yelp.com/search?find_desc=Restaurants&find_loc=La+Crosse,+WI&start=0
# Loading https://www.yelp.com/search?find_desc=Restaurants&find_loc=La+Crosse,+WI&start=30
# Loading https://www.yelp.com/search?find_desc=Restaurants&find_loc=La+Crosse,+WI&start=60
# Loading https://www.yelp.com/search?find_desc=Restaurants&find_loc=La+Crosse,+WI&start=90
# Loading https://www.yelp.com/search?find_desc=Restaurants&find_loc=La+Crosse,+WI&start=120
# Loading https://www.yelp.com/search?find_desc=Restaurants&find_loc=La+Crosse,+WI&start=150
# Loading https://www.yelp.com/search?find_desc=Restaurants&find_loc=La+Crosse,+WI&start=180
# Loading https://www.yelp.com/search?find_desc=Restaurants&find_loc=La+Crosse,+WI&start=210

# %% [markdown]
# ### Step 2 - Get the info from each soup

# %%
info = [get_page_info(soup) for soup in soups]
info
# Out:
# [[('The Waterfront Restaurant & Tavern',
#    '4.5',
#    '328 Front St S',
#    '182',
#    'American (New);Seafood;Steakhouses'),
#   ('Buzzard Billy’s',
#    '4.0',
#    '222 Pearl St',
#    '203',
#    'American (Traditional);Cajun/Creole'),
#   ('Greengrass Cafe',
#    '4.0',
#    '1904 Campbell Rd',
#    '85',
#    'Breakfast & Brunch;Bars'),
#   ('Lovechild Restaurant',
#    '4.5',
#    '300 3rd St S',
#    '75',
#    'Salad;Bars;Steakhouses'),
#   ('The Charmant', '4.5', '101 State St', '125', 'French;American (New)'),
#   ('The Root Note',
#    '4.5',
#    '115 4th St S',
#    '65',
#    'Music Venues;Coffee & Tea;Creperies'),
#   ('Piggy’s Restaurant',
#    '4.0',
#    '501 Front St S',
#    '109',
#    'Steakhouses;Seafood;Sandwiches'),
#   ('Howie’s on La Crosse',
#    '4.0',
#    '1128 La Crosse St',
#    '50',
#    'American (New);Pubs'),
#   ('Kate’s On State', '4.0', '333 Main St', '79', 'Italian;Seafood'),
#   ('Dublin Square Irish Pub & Eatery',
#    '4.0',
#    '103 3rd St N',
#    '173',
#    'American (Traditional);Irish Pub'),
#   ('The Freighthouse Restaurant',
#    '4.0',
#    '107 Vine St',
#    '104',
#    'Seafood;Steakhouses;Desserts'),
#   ('Digger’s Sting Restaurant',
#    '4.0',
#    '122 3rd St N',
#    '50',
#    'American (New);Steakhouses'),
#   ('The Breakfast Club and Pub',
#    '3.5',
#    '214 Main St',
#    '81',
#    'American (Traditional);Breakfast & Brunch;Pubs'),
#   ('Le Chateau', '4.5', '410 Cass St', '46', 'French;Wine Bars;Cocktail Bars'),
#   ('Rosie’s Cafe',
#    '4.5',
#    '2225 16th St S',
#    '35',
#    'Diners;Cafes;American (Traditional)'),
#   ('Thao’s Thai Restaurant and Deli',
#    '3.5',
#    '1203 La Crosse St',
#    '18',
#    'Thai;Delis'),
#   ('Fayze’s',
#    '3.5',
#    '135 S 4th St',
#    '117',
#    'Bakeries;American (Traditional);Pubs'),
#   ('La Crosse Family Restaurant',
#    '4.0',
#    '2120 Rose St',
#    '51',
#    'American (Traditional);Breakfast & Brunch'),
#   ('The Crow',
#    '3.5',
#    '100 3rd St S',
#    '105',
#    'American (Traditional);Salad;Gastropubs'),
#   ('Stein Haus', '4.0', '324 Jay St', '32', 'German;Pubs'),
#   ('Burritos House', '4.5', '1205 La Crosse St', '31', 'Mexican'),
#   ('Iguana’s Mexican Street Café', '4.0', '1800 State St', '66', 'Mexican'),
#   ('Hungry Peddler',
#    '4.0',
#    '3429 Mormon Coulee Rd',
#    '46',
#    'American (Traditional);Steakhouses;Seafood'),
#   ('Press Break', '5.0', '146 Rose St', '7', 'Sandwiches;Soup;Hot Dogs'),
#   ('Hmong’s Golden Egg Roll',
#    '4.0',
#    '901 State St',
#    '53',
#    'Laotian;Vietnamese;Thai'),
#   ('Pickerman’s Soup & Sandwiches',
#    '4.5',
#    '327 Jay St',
#    '45',
#    'Sandwiches;Soup'),
#   ('Señor Villa', '4.0', '325 West Ave N', '44', 'Mexican'),
#   ('Pizza Amoré', '4.0', '212 Main St NE', '66', 'Pizza'),
#   ('Red Pines Bar & Grill',
#    '4.5',
#    'W7305 County Rd Z',
#    '64',
#    'American (Traditional);Seafood'),
#   ('River Rats Bar and Grill',
#    '4.5',
#    '1311 La Crescent Pl',
#    '14',
#    'American (New);Burgers;Cocktail Bars')],
#  [('Uptowne Cafe & Bakery',
#    '4.0',
#    '1217 Caledonia St',
#    '27',
#    'Bakeries;Cafes;Breakfast & Brunch'),
#   ('4 Sisters Wine Bar and Tapas',
#    '3.5',
#    '100 Harborview Plz',
#    '93',
#    'Wine Bars;Tapas/Small Plates;Tapas Bars'),
#   ('Nosh', '5.0', '3800 WI-16', '5', 'Cafes'),
#   ('Schmitty’s TimeOut Tavern',
#    '5.0',
#    '444 N Chestnut St',
#    '4',
#    'Chicken Wings;American (Traditional);Burgers'),
#   ('Burger Fusion Company',
#    '4.0',
#    '1812 Jackson St',
#    '45',
#    'Burgers;American (Traditional)'),
#   ('New Taste of India', '4.0', '214 Main St', '97', 'Indian'),
#   ('David Reay’s Modern Diner + Tavern',
#    '4.0',
#    'W4516 Eddie Ave',
#    '61',
#    'Diners;Bars'),
#   ('Timmers 10 Mile Pub',
#    '4.5',
#    '1004 La Crosse St',
#    '11',
#    'Pubs;American (Traditional)'),
#   ('Rudy’s Drive-In',
#    '4.5',
#    "Dave's Guitar Shop Parking Lot",
#    '37',
#    'American (New)'),
#   ('Big Mama’s Gyros', '5.0', '111 Front St S', '9', 'Greek;Street Vendors'),
#   ('Three Rivers Lodge River View Restaurant and Bar',
#    '3.5',
#    '828 5th Ave S',
#    '22',
#    'Bars;American (New);Breakfast & Brunch'),
#   ('Ye Old Style Inn',
#    '4.5',
#    '236 E Main St',
#    '4',
#    'Beer Bar;Breakfast & Brunch;Wraps'),
#   ('Kaddy’s Kafe', '4.5', '129 Marina Dr', '16', 'Breakfast & Brunch;Cafes'),
#   ('Huck Finn’s On the Water',
#    '3.0',
#    '2311 State Rd',
#    '39',
#    'American (Traditional);Music Venues;Chicken Wings'),
#   ('JavaVino',
#    '4.0',
#    '221 Pearl St',
#    '29',
#    'Wine Bars;Coffee & Tea;Breakfast & Brunch'),
#   ('Dim Sum Tea Shop', '4.0', '58 Copeland Ave', '36', 'Dim Sum;Coffee & Tea'),
#   ('Great Harvest Bread Company',
#    '4.5',
#    '115 5th Ave S',
#    '5',
#    'Bakeries;Sandwiches'),
#   ('El Rodeo Restaurant', '4.0', '2846 Midwest Dr', '20', 'Mexican'),
#   ('Ciatti’s Italian Grill',
#    '4.5',
#    '128 3rd St S',
#    '39',
#    'Seafood;Steakhouses;Italian'),
#   ('The Twisted Moose',
#    '2.5',
#    '1002 Jackson St',
#    '25',
#    'Bars;American (Traditional);Comfort Food'),
#   ('Houghton’s Jackson Street Pub',
#    '3.5',
#    '1232 Avon St',
#    '24',
#    'American (Traditional);Irish Pub;Steakhouses'),
#   ('Pogreba Restaurant',
#    '3.5',
#    '322 Main St',
#    '36',
#    'American (Traditional);Seafood;Steakhouses'),
#   ('Great Wall', '3.5', '200 Main St', '22', 'Chinese;Asian Fusion'),
#   ('Sushi Pirate', '3.5', '400 Lang Dr', '43', 'Japanese;Sushi Bars'),
#   ('Ardie’s Restaurant / Flipside Pub & Grill',
#    '3.5',
#    '2526 Rose St',
#    '25',
#    'American (Traditional);Sports Bars;Pubs'),
#   ('North Country Steak Buffet',
#    '4.0',
#    '3514 Mormon Coulee Rd',
#    '24',
#    'Buffets;Steakhouses'),
#   ('Marco’s Pizza', '4.5', '205 S Holmen Dr', '7', 'Pizza'),
#   ('Taste of Thai', '4.0', '1914 Campbell Rd', '25', 'Thai'),
#   ('Eagle’s Nest Sports Bar & Grill',
#    '3.5',
#    '3119 State Rd',
#    '15',
#    'Sports Bars;American (Traditional)')],
#  [('River Rocks Coffee',
#    '4.0',
#    '332 Front St S',
#    '4',
#    'Coffee & Tea;Breakfast & Brunch;Bagels'),
#   ('Hackberry’s Bistro',
#    '3.5',
#    '315 5th Ave S',
#    '32',
#    'Cafes;Breakfast & Brunch'),
#   ('Tom Sawyer’s Bar & Grill',
#    '3.5',
#    '136 Clinton St',
#    '23',
#    'Bars;Burgers;Mexican'),
#   ('Fox Hollow Sports Bar',
#    '4.5',
#    'N3287 County Rd OA',
#    '10',
#    'American (Traditional);Sports Bars'),
#   ('Royal Indian Cuisine', '4.5', '235 Sand Lake Rd', '56', 'Indian'),
#   ('Arterial',
#    '3.5',
#    '1003 16th St S',
#    '15',
#    'Bars;American (Traditional);Breakfast & Brunch'),
#   ('Pizza King-Pizza Subs Gyros',
#    '4.5',
#    '2929 S Ave',
#    '12',
#    'Pizza;Italian;Greek'),
#   ('Shogun Sushi And Hibachi',
#    '4.0',
#    '1227 Crossing Meadows Dr',
#    '52',
#    'Japanese;Sushi Bars'),
#   ('Bean Juice', '4.5', '1014 19th St S', '16', 'Coffee & Tea;Sandwiches'),
#   ('Nutbush City Limits',
#    '3.0',
#    '3264 George St',
#    '27',
#    'Bars;Breakfast & Brunch;American (Traditional)'),
#   ('Shenanigans Entertainment Center & Sports Bar',
#    '2.5',
#    '2100 Dawson Ave',
#    '13',
#    'Arcades;Party & Event Planning;American (Traditional)'),
#   ('Rivoli Theatre & Pizzeria', '4.0', '117 4th St N', '35', 'Cinema;Pizza'),
#   ('Moxie’s', '3.0', '1835 Rose St', '4', 'American (New);Tiki Bars'),
#   ('Culina Mariana Cafe',
#    '4.0',
#    '5250 Justin Rd',
#    '3',
#    'American (New);German;Breakfast & Brunch'),
#   ('Fiesta Mexicana', '4.0', '5200 Mormon Coulee Rd', '20', 'Mexican'),
#   ('Polito’s Pizza', '3.5', '116 3rd St S', '27', 'Pizza'),
#   ('Big Al’s Pizza', '3.0', '115 3rd St', '51', 'Pizza'),
#   ('Linda’s Bakery',
#    '5.0',
#    '190 E City Hwy 16',
#    '18',
#    'Bakeries;Donuts;Gluten-Free'),
#   ('Gracie’s Gyros & Wraps',
#    '3.0',
#    '1908 Campbell Rd',
#    '28',
#    'Bakeries;Greek'),
#   ('Big Boar Barbecue & Catering', '4.5', '510 Commerce Dr', '39', 'Barbeque'),
#   ('Angelini’s Ristorante', '3.5', '1427 State Hwy 35', '31', 'Italian;Pizza'),
#   ('Cabin Coffee', '4.0', '401 Jay St', '21', 'Coffee & Tea;Sandwiches'),
#   ('Two Beagles Brewpub',
#    '3.0',
#    '910 2nd Ave N',
#    '36',
#    'American (New);Brewpubs'),
#   ('The Verse Lounge & Grill',
#    '5.0',
#    '717 Rose St',
#    '1',
#    'Lounges;American (Traditional)'),
#   ('Kramer’s Bar & Grill', '4.0', '1123 3rd St S', '6', 'Restaurants'),
#   ('King Street Kitchen',
#    '3.5',
#    '141 7th St S',
#    '7',
#    'American (Traditional);Breakfast & Brunch;Venues & Event Spaces'),
#   ('Dewey’s Side Street Saloon',
#    '3.0',
#    '621 Saint Paul St',
#    '2',
#    'Bars;American (Traditional);Music Venues'),
#   ('Barre Country Diner',
#    '4.0',
#    'W4007 Country Rd 0',
#    '8',
#    'Diners;Breakfast & Brunch;Pizza'),
#   ('El Cerrito', '4.0', '306 Sand Lake Rd', '13', 'Mexican'),
#   ('4 Sisters 4th Street Bar and Catering',
#    '3.5',
#    '133 4th St S',
#    '9',
#    'Wine Bars;Tapas Bars;Tapas/Small Plates')],
#  [('The Ridge',
#    '4.0',
#    'W2782 State Rd 33',
#    '5',
#    'Bars;American (Traditional)'),
#   ('Blue Moon Restaurant',
#    '3.5',
#    '716 2nd Ave N',
#    '45',
#    'American (Traditional);Breakfast & Brunch'),
#   ('Sloopy’s Alma Mater',
#    '3.5',
#    '163 Copeland Ave',
#    '8',
#    'Chicken Wings;Pizza;Sandwiches'),
#   ('Pla-Mor Lanes and The Eleventh Frame Diner',
#    '5.0',
#    '807 4th St S',
#    '6',
#    'Bowling;Pizza;American (Traditional)'),
#   ('Famous Dave’s',
#    '4.0',
#    '3055 State Rd 16',
#    '28',
#    'Barbeque;American (Traditional);Comfort Food'),
#   ('Hunan Chinese Restaurant & Lounge',
#    '3.0',
#    '318 4th St S',
#    '20',
#    'Chinese'),
#   ('Marge’s On Rose', '3.0', '833 Rose St', '40', 'Breakfast & Brunch'),
#   ('Maggie’s On Main', '3.0', '205 Main St', '16', 'Breakfast & Brunch'),
#   ('Tequila Mexican Restaurant', '2.5', '515 West Ave N', '16', 'Mexican'),
#   ('Cabin Coffee La Crosse North',
#    '5.0',
#    '2843 Darling Ct',
#    '2',
#    'Coffee & Tea;Breakfast & Brunch;Bagels'),
#   ('Quillin’s', '5.0', '24 S Walnut St', '1', 'Grocery;Delis'),
#   ('Lindy’s Subs & Salads', '3.5', '221 Main St', '23', 'Sandwiches;Salad'),
#   ('Burger Fusion Company',
#    '2.5',
#    '200 Pearl St',
#    '18',
#    'Burgers;Ice Cream & Frozen Yogurt;Sandwiches'),
#   ('Alpine Inn',
#    '3.5',
#    'W5717 Bliss Rd',
#    '17',
#    'Bars;Burgers;American (Traditional)'),
#   ('The Barrel Bar & Grill',
#    '4.0',
#    '2005 West Ave S',
#    '5',
#    'Sports Bars;American (Traditional)'),
#   ('QDOBA Mexican Eats', '3.5', '127 S 3rd St', '14', 'Mexican;Fast Food'),
#   ('Al’s State Road Pizzeria', '3.5', '2242 State Rd', '9', 'Pizza'),
#   ('Texas Roadhouse',
#    '3.5',
#    '4310 State Hwy 16',
#    '34',
#    'Barbeque;Steakhouses'),
#   ('B.A. Burrito Co.', '3.0', '40 Copeland Ave', '26', 'Tex-Mex;Mexican'),
#   ('Pizza Doctors', '3.0', '624 King St', '34', 'Pizza;Buffets'),
#   ('Pettibone Boat Club',
#    '2.5',
#    'S Pettibone Dr',
#    '34',
#    'Burgers;American (Traditional);Sandwiches'),
#   ('Super Buffet', '2.0', '206 Copeland Ave', '9', 'Chinese;Buffets'),
#   ('Fox Hollow Golf Course',
#    '5.0',
#    'N3287 County Trunk Oa',
#    '5',
#    'Golf;Burgers;Venues & Event Spaces'),
#   ('Golden China', '4.5', '920 W City Hwy 16', '10', 'Chinese'),
#   ('CreekSide Grill and Pub',
#    '4.0',
#    'W5450 Keil Coulee Rd',
#    '4',
#    'Pubs;American (Traditional);Italian'),
#   ('Huhot Mongolian Grill',
#    '3.5',
#    '1501 Saint Andrew St',
#    '24',
#    'Chinese;Asian Fusion;Mongolian'),
#   ('Boot Hill Pub', '3.5', '101 3rd St S', '7', 'Pubs;Burgers;Sandwiches'),
#   ('Bebo’s Dogs & Beef', '5.0', '311 Hampton Ct', '1', 'Hot Dogs'),
#   ('Outback Steakhouse', '3.0', '3039 Medco Ct', '28', 'Steakhouses')],
#  [('Castaways on the Island', '2.0', '131 Clinton St', '1', 'Restaurants'),
#   ('Olive Garden Italian Restaurant',
#    '3.0',
#    '9413 State Rd 16',
#    '29',
#    'Italian;Salad'),
#   ('China Buffet', '2.5', '1611 Losey Blvd S', '14', 'Chinese'),
#   ('Manny’s Mexican Cocina', '3.5', '301 Hampton Ct', '87', 'Mexican'),
#   ('Domino’s Pizza',
#    '4.5',
#    '2402 State Rd',
#    '5',
#    'Pizza;Chicken Wings;Sandwiches'),
#   ('Panera Bread', '3.0', '400 7th St N', '30', 'Sandwiches;Salad;Soup'),
#   ('Union Market', '4.0', '1411 Rose St', '1', 'Restaurants'),
#   ('Perkins Restaurant & Bakery',
#    '2.5',
#    'N5914 County Rd Zz',
#    '21',
#    'Bakeries;Breakfast & Brunch;American (Traditional)'),
#   ('Angry’s Way Out',
#    '5.0',
#    '315 West Avenue North',
#    '1',
#    'Bars;American (Traditional);Chicken Wings'),
#   ('Taco Bell',
#    '2.5',
#    '325 West Avenue North',
#    '6',
#    'Mexican;Tex-Mex;Fast Food'),
#   ('Señor Villa', '4.0', '325 West Ave N', '6', 'Mexican;Bars;Seafood'),
#   ('Coney Island Hot Dogs', '4.0', '1717 George St', '7', 'Hot Dogs'),
#   ('Toppers Pizza', '3.0', 'N5610 County Rd Ot', '5', 'Pizza'),
#   ('T-Jo’s Pizza', '3.0', '702 Main St', '12', 'Pizza;Sandwiches'),
#   ('Midway Deli', '4.0', '40 Copeland Ave', '8', 'Delis'),
#   ('Saxon Hall', '4.5', '1111 S Third St', '6', 'Pizza'),
#   ('Rocky Rococo - La Crosse',
#    '2.5',
#    '4202 Mormon Coulee Rd',
#    '7',
#    'Pizza;Italian'),
#   ('Nell’s City Grill', '4.0', '205 Main St', '4', 'American (Traditional)'),
#   ('China Star', '2.5', '1205 La Crosse St', '24', 'Chinese'),
#   ('Mary Cody’s Restaurant and Maggie’s Lounge',
#    '3.5',
#    '101 Sky Harbour Dr',
#    '16',
#    'American (New)'),
#   ('Subway', '4.0', '3132 Market Pl', '2', 'Sandwiches;Fast Food'),
#   ('Heroes Bar and Grill', '3.5', '1607 Losey Blvd S', '3', 'Bars;Sandwiches'),
#   ('Buffalo Wild Wings',
#    '3.0',
#    '312 Pearl St',
#    '38',
#    'Chicken Wings;American (Traditional);Sports Bars'),
#   ('B.A. Burrito', '3.0', '835 Oak Ave S', '12', 'Mexican;Tex-Mex'),
#   ('Jimmy John’s',
#    '3.0',
#    '9432 State Rd 16',
#    '15',
#    'Sandwiches;Delis;Fast Food'),
#   ('Culver’s',
#    '4.5',
#    '114 4th St S',
#    '3',
#    'Burgers;Ice Cream & Frozen Yogurt;Fast Food'),
#   ('Burrachos Fresh Mexican Grill',
#    '3.5',
#    '9396 State Rd 16',
#    '20',
#    'Mexican'),
#   ('Coney Island', '2.5', '988 12th Ave S', '7', 'Hot Dogs;Burgers')],
#  [('Subway', '4.0', '202 3rd St S', '4', 'Sandwiches;Fast Food'),
#   ('Cedar Creek', '4.0', '2600 Cedar Creek Ln', '1', 'Restaurants'),
#   ('Fazoli’s', '3.5', '9370 Hwy 16', '13', 'Italian'),
#   ('China Max', '4.0', 'Valley View Mall', '4', 'Chinese'),
#   ('McDonald’s',
#    '4.5',
#    '2437 W George St',
#    '3',
#    'Coffee & Tea;Burgers;Fast Food'),
#   ('The Pizza Oven', '4.5', '920 W Hwy 16', '4', 'Pizza'),
#   ('Papa Murphy’s', '5.0', '1820 Jackson Street', '1', 'Pizza'),
#   ('Culver’s',
#    '3.5',
#    '4101 Mormon Coulee Rd',
#    '10',
#    'Burgers;Ice Cream & Frozen Yogurt;Fast Food'),
#   ('Jim Dandy’s tasty eats & frozen treats',
#    '4.5',
#    '201 Hwy 16',
#    '5',
#    'American (Traditional);Ice Cream & Frozen Yogurt'),
#   ('TGI Fridays', '2.5', '9416 Highway 16', '20', 'American (Traditional)'),
#   ('Red Lobster',
#    '2.5',
#    '3333 State Rd 16',
#    '11',
#    'Seafood;American (Traditional)'),
#   ('The MOB Stop', '4.5', '208 S Holmen Dr', '6', 'Hot Dogs;Food Stands'),
#   ('Taco John’s', '2.5', '1211 Jackson St', '8', 'Mexican;Fast Food'),
#   ('Jimmy John’s',
#    '4.5',
#    '1420 Losey Blvd S',
#    '3',
#    'Delis;Sandwiches;Fast Food'),
#   ('South Lanes Pizza and wings',
#    '3.0',
#    '1125 Main St',
#    '5',
#    'Pizza;Bowling;Chicken Wings'),
#   ('Caribou Coffee',
#    '4.0',
#    '1202 County Rd Ph',
#    '12',
#    'Bakeries;Coffee & Tea;Sandwiches'),
#   ('China Inn', '2.5', '9348 State Rd 16', '12', 'Chinese'),
#   ('Applebee’s Grill + Bar',
#    '1.5',
#    '9364 Hwy 16',
#    '27',
#    'Sports Bars;Burgers;American (Traditional)'),
#   ('South Lanes Pizza',
#    '2.5',
#    '4107 Mormon Coulee Rd',
#    '5',
#    'Pizza;Bowling;Bars'),
#   ('T.G.I. Friday’s', '4.0', '9430 State Rd 16', '6', 'American (New)'),
#   ('KFC', '3.0', '2001 Rose St', '5', 'Fast Food;Chicken Wings;Chicken Shop'),
#   ('Tequila’s Restaurant', '3.0', '425 2nd Ave S', '11', 'Mexican'),
#   ('A & W Family Restaurant', '2.5', '3005 South Ave', '10', 'Fast Food'),
#   ('Pizza Hut', '2.5', '2212 Rose St', '8', 'Pizza;Italian'),
#   ('Features Sports Bar & Grill',
#    '3.0',
#    '1425 State Hwy 16',
#    '18',
#    'Bowling;Sports Bars;Burgers'),
#   ('Lindy’s Subs & Salads',
#    '4.0',
#    '225 Sand Lake Rd',
#    '14',
#    'Salad;Fruits & Veggies'),
#   ('Culver’s',
#    '3.5',
#    '9422 State Rd 16',
#    '5',
#    'Burgers;Fast Food;Ice Cream & Frozen Yogurt'),
#   ('Sidewalk Cafe', '3.5', '46 Main St', '3', 'Breakfast & Brunch;Burgers'),
#   ('Corky’s Pizza',
#    '3.0',
#    '25 S Walnut St',
#    '10',
#    'Pizza;Ice Cream & Frozen Yogurt;Burgers'),
#   ('Big Al’s Too', '3.5', '103 10th Ave S', '3', 'Pizza')],
#  [('Pizza Corral', '4.0', '1505 S Holmen Dr', '20', 'Pizza'),
#   ('Dairy Queen',
#    '3.5',
#    '4200 Mormon Coulee Rd',
#    '3',
#    'Fast Food;Ice Cream & Frozen Yogurt'),
#   ('Little Caesars Pizza', '1.5', '1022 La Crosse St', '3', 'Italian;Pizza'),
#   ('Arrowhead Tap House',
#    '1.0',
#    '2956 Airport Dr',
#    '1',
#    'American (Traditional)'),
#   ('Toppers Pizza', '3.0', '605 2nd Ave S', '5', 'Pizza'),
#   ('Pizza Hut', '2.0', '2028 Ward Ave', '6', 'Pizza;Italian;Chicken Wings'),
#   ('Hunter’s Last Chance',
#    '4.5',
#    '150 S Leonard St',
#    '4',
#    'Sports Bars;Burgers;Pizza'),
#   ('Rocky Rococo Pan Style Pizza',
#    '3.0',
#    '1239 Crossing Meadows Dr',
#    '6',
#    'Pizza;Italian'),
#   ('Domino’s Pizza',
#    '3.5',
#    '224 Sand Lake Rd',
#    '6',
#    'Pizza;Chicken Wings;Sandwiches'),
#   ('Mexican Tamales Restaurant', '2.5', '306 Sand Lake Rd', '12', 'Mexican'),
#   ('Hardee’s', '2.5', '1311 Rose St', '9', 'Fast Food'),
#   ('Jacqlons Cafe', '3.0', '512 S Main St', '4', 'Cafes'),
#   ('Westview Inn', '3.5', '174 Leonard St S', '6', 'American (New)'),
#   ('Chuck E Cheese’s', '3.5', '4444 State Rd 16', '4', 'Pizza;Arcades'),
#   ('Burger King', '1.0', '515 4th St N', '1', 'Restaurants'),
#   ('Perkins Restaurant & Bakery',
#    '3.0',
#    '9428 Highway 16',
#    '16',
#    'Bakeries;Breakfast & Brunch;American (Traditional)'),
#   ('Rocky Rococo Pan Style Pizza', '2.5', '3800 State Rd 16', '2', 'Pizza'),
#   ('Wendy’s', '2.0', '4422 Mormon Coulee Rd', '3', 'Fast Food;Burgers'),
#   ('Taco John’s', '1.0', '602 Monitor St', '2', 'Fast Food;Mexican'),
#   ('The Bistro', '2.0', '500 Front St', '3', 'American (Traditional)'),
#   ('Ringside', '3.0', '223 Pearl St', '1', 'American (New)'),
#   ('Taco Bell',
#    '3.5',
#    '1243 Crossing Meadows Rd',
#    '3',
#    'Tex-Mex;Fast Food;Mexican'),
#   ('Super Buffet Chinese Restaurant',
#    '1.5',
#    '9348 Highway 16',
#    '3',
#    'Chinese'),
#   ('Papa Murphy’s', '2.5', '1220 Crossing Meadows Drive', '6', 'Pizza'),
#   ('Copper Penny', '3.0', '200 Main St', '1', 'Restaurants'),
#   ('Pizza Villa West Salem', '4.0', '156 Leonard St S', '2', 'Pizza'),
#   ('Dairy Queen',
#    '2.0',
#    '810 2nd Ave S',
#    '9',
#    'Ice Cream & Frozen Yogurt;Fast Food'),
#   ('McDonald’s',
#    '1.5',
#    '2810 Losey Blvd S',
#    '4',
#    'Fast Food;Burgers;Coffee & Tea'),
#   ('Arby’s', '3.0', '3210 N Kinney Coulee Rd', '2', 'Fast Food;Sandwiches'),
#   ('Burger King', '1.0', '3519 Mormon Coulee Rd', '3', 'Burgers;Fast Food')],
#  [('T Jo’s Pizza & Sandwich Shop', '4.5', '105 State St', '6', 'Pizza'),
#   ('Taco Bell',
#    '1.0',
#    '4141 Mormon Coulee Ct',
#    '9',
#    'Mexican;Tex-Mex;Fast Food'),
#   ('Jimmy John’s',
#    '3.0',
#    '9432 State Rd 16',
#    '7',
#    'Sandwiches;Delis;Fast Food'),
#   ('KFC',
#    '1.5',
#    '3415 Fiesta Ct',
#    '4',
#    'Chicken Wings;Fast Food;Chicken Shop'),
#   ('Subway', '3.5', '9360 State Rd 16', '4', 'Sandwiches;Fast Food'),
#   ('Hearty Platter Cafe',
#    '4.0',
#    '42165 Csah 12',
#    '1',
#    'Cafes;Travel Services'),
#   ('Primos Southwestern Grill',
#    '1.5',
#    '1427 Hwy 35',
#    '5',
#    'American (Traditional);Mexican'),
#   ('Coney Island Hot Dogs', '3.0', '3800 Hwy 16', '6', 'Hot Dogs'),
#   ('Joe’s Bar & Grill At Days Inn',
#    '1.0',
#    '101 Sky Harbour Dr',
#    '1',
#    'Bars;American (Traditional)'),
#   ('Subway', '1.0', '3810 Mormon Coulee Rd', '1', 'Sandwiches;Fast Food'),
#   ('Burger King', '1.5', '1124 George St W', '3', 'Restaurants'),
#   ('Wendy’s', '1.0', '9346 State Rd 16', '4', 'Burgers;Fast Food'),
#   ('American Legion Clubroom', '2.5', '509 N Chestnut St', '3', 'Restaurants'),
#   ('Subway', '3.0', '420 Commerce St', '2', 'Sandwiches;Fast Food'),
#   ('McDonald’s',
#    '1.0',
#    '9398 State Road 16',
#    '1',
#    'Fast Food;Burgers;Coffee & Tea'),
#   ('Truckers Inn Restaurant', '2.0', 'I 90 & County 12', '1', 'Restaurants'),
#   ('Burger King', '1.5', '1259 Crossing Meadows Dr', '4', 'Sandwiches'),
#   ('Subway', '1.0', '301 Kistler Dr', '1', 'Sandwiches;Fast Food')]]

# %% [markdown]
# ## Stinky Cabbage!
#
# Let's hold our nose and use double `for` loops to print the contents of `info`

# %%
for inner_list in info:
    for row in inner_list:
        print(row)
# Out:
# ('The Waterfront Restaurant & Tavern', '4.5', '328 Front St S', '182', 'American (New);Seafood;Steakhouses')
# ('Buzzard Billy’s', '4.0', '222 Pearl St', '203', 'American (Traditional);Cajun/Creole')
# ('Greengrass Cafe', '4.0', '1904 Campbell Rd', '85', 'Breakfast & Brunch;Bars')
# ('Lovechild Restaurant', '4.5', '300 3rd St S', '75', 'Salad;Bars;Steakhouses')
# ('The Charmant', '4.5', '101 State St', '125', 'French;American (New)')
# ('The Root Note', '4.5', '115 4th St S', '65', 'Music Venues;Coffee & Tea;Creperies')
# ('Piggy’s Restaurant', '4.0', '501 Front St S', '109', 'Steakhouses;Seafood;Sandwiches')
# ('Howie’s on La Crosse', '4.0', '1128 La Crosse St', '50', 'American (New);Pubs')
# ('Kate’s On State', '4.0', '333 Main St', '79', 'Italian;Seafood')
# ('Dublin Square Irish Pub & Eatery', '4.0', '103 3rd St N', '173', 'American (Traditional);Irish Pub')
# ('The Freighthouse Restaurant', '4.0', '107 Vine St', '104', 'Seafood;Steakhouses;Desserts')
# ('Digger’s Sting Restaurant', '4.0', '122 3rd St N', '50', 'American (New);Steakhouses')
# ('The Breakfast Club and Pub', '3.5', '214 Main St', '81', 'American (Traditional);Breakfast & Brunch;Pubs')
# ('Le Chateau', '4.5', '410 Cass St', '46', 'French;Wine Bars;Cocktail Bars')
# ('Rosie’s Cafe', '4.5', '2225 16th St S', '35', 'Diners;Cafes;American (Traditional)')
# ('Thao’s Thai Restaurant and Deli', '3.5', '1203 La Crosse St', '18', 'Thai;Delis')
# ('Fayze’s', '3.5', '135 S 4th St', '117', 'Bakeries;American (Traditional);Pubs')
# ('La Crosse Family Restaurant', '4.0', '2120 Rose St', '51', 'American (Traditional);Breakfast & Brunch')
# ('The Crow', '3.5', '100 3rd St S', '105', 'American (Traditional);Salad;Gastropubs')
# ('Stein Haus', '4.0', '324 Jay St', '32', 'German;Pubs')
# ('Burritos House', '4.5', '1205 La Crosse St', '31', 'Mexican')
# ('Iguana’s Mexican Street Café', '4.0', '1800 State St', '66', 'Mexican')
# ('Hungry Peddler', '4.0', '3429 Mormon Coulee Rd', '46', 'American (Traditional);Steakhouses;Seafood')
# ('Press Break', '5.0', '146 Rose St', '7', 'Sandwiches;Soup;Hot Dogs')
# ('Hmong’s Golden Egg Roll', '4.0', '901 State St', '53', 'Laotian;Vietnamese;Thai')
# ('Pickerman’s Soup & Sandwiches', '4.5', '327 Jay St', '45', 'Sandwiches;Soup')
# ('Señor Villa', '4.0', '325 West Ave N', '44', 'Mexican')
# ('Pizza Amoré', '4.0', '212 Main St NE', '66', 'Pizza')
# ('Red Pines Bar & Grill', '4.5', 'W7305 County Rd Z', '64', 'American (Traditional);Seafood')
# ('River Rats Bar and Grill', '4.5', '1311 La Crescent Pl', '14', 'American (New);Burgers;Cocktail Bars')
# ('Uptowne Cafe & Bakery', '4.0', '1217 Caledonia St', '27', 'Bakeries;Cafes;Breakfast & Brunch')
# ('4 Sisters Wine Bar and Tapas', '3.5', '100 Harborview Plz', '93', 'Wine Bars;Tapas/Small Plates;Tapas Bars')
# ('Nosh', '5.0', '3800 WI-16', '5', 'Cafes')
# ('Schmitty’s TimeOut Tavern', '5.0', '444 N Chestnut St', '4', 'Chicken Wings;American (Traditional);Burgers')
# ('Burger Fusion Company', '4.0', '1812 Jackson St', '45', 'Burgers;American (Traditional)')
# ('New Taste of India', '4.0', '214 Main St', '97', 'Indian')
# ('David Reay’s Modern Diner + Tavern', '4.0', 'W4516 Eddie Ave', '61', 'Diners;Bars')
# ('Timmers 10 Mile Pub', '4.5', '1004 La Crosse St', '11', 'Pubs;American (Traditional)')
# ('Rudy’s Drive-In', '4.5', "Dave's Guitar Shop Parking Lot", '37', 'American (New)')
# ('Big Mama’s Gyros', '5.0', '111 Front St S', '9', 'Greek;Street Vendors')
# ('Three Rivers Lodge River View Restaurant and Bar', '3.5', '828 5th Ave S', '22', 'Bars;American (New);Breakfast & Brunch')
# ('Ye Old Style Inn', '4.5', '236 E Main St', '4', 'Beer Bar;Breakfast & Brunch;Wraps')
# ('Kaddy’s Kafe', '4.5', '129 Marina Dr', '16', 'Breakfast & Brunch;Cafes')
# ('Huck Finn’s On the Water', '3.0', '2311 State Rd', '39', 'American (Traditional);Music Venues;Chicken Wings')
# ('JavaVino', '4.0', '221 Pearl St', '29', 'Wine Bars;Coffee & Tea;Breakfast & Brunch')
# ('Dim Sum Tea Shop', '4.0', '58 Copeland Ave', '36', 'Dim Sum;Coffee & Tea')
# ('Great Harvest Bread Company', '4.5', '115 5th Ave S', '5', 'Bakeries;Sandwiches')
# ('El Rodeo Restaurant', '4.0', '2846 Midwest Dr', '20', 'Mexican')
# ('Ciatti’s Italian Grill', '4.5', '128 3rd St S', '39', 'Seafood;Steakhouses;Italian')
# ('The Twisted Moose', '2.5', '1002 Jackson St', '25', 'Bars;American (Traditional);Comfort Food')
# ('Houghton’s Jackson Street Pub', '3.5', '1232 Avon St', '24', 'American (Traditional);Irish Pub;Steakhouses')
# ('Pogreba Restaurant', '3.5', '322 Main St', '36', 'American (Traditional);Seafood;Steakhouses')
# ('Great Wall', '3.5', '200 Main St', '22', 'Chinese;Asian Fusion')
# ('Sushi Pirate', '3.5', '400 Lang Dr', '43', 'Japanese;Sushi Bars')
# ('Ardie’s Restaurant / Flipside Pub & Grill', '3.5', '2526 Rose St', '25', 'American (Traditional);Sports Bars;Pubs')
# ('North Country Steak Buffet', '4.0', '3514 Mormon Coulee Rd', '24', 'Buffets;Steakhouses')
# ('Marco’s Pizza', '4.5', '205 S Holmen Dr', '7', 'Pizza')
# ('Taste of Thai', '4.0', '1914 Campbell Rd', '25', 'Thai')
# ('Eagle’s Nest Sports Bar & Grill', '3.5', '3119 State Rd', '15', 'Sports Bars;American (Traditional)')
# ('River Rocks Coffee', '4.0', '332 Front St S', '4', 'Coffee & Tea;Breakfast & Brunch;Bagels')
# ('Hackberry’s Bistro', '3.5', '315 5th Ave S', '32', 'Cafes;Breakfast & Brunch')
# ('Tom Sawyer’s Bar & Grill', '3.5', '136 Clinton St', '23', 'Bars;Burgers;Mexican')
# ('Fox Hollow Sports Bar', '4.5', 'N3287 County Rd OA', '10', 'American (Traditional);Sports Bars')
# ('Royal Indian Cuisine', '4.5', '235 Sand Lake Rd', '56', 'Indian')
# ('Arterial', '3.5', '1003 16th St S', '15', 'Bars;American (Traditional);Breakfast & Brunch')
# ('Pizza King-Pizza Subs Gyros', '4.5', '2929 S Ave', '12', 'Pizza;Italian;Greek')
# ('Shogun Sushi And Hibachi', '4.0', '1227 Crossing Meadows Dr', '52', 'Japanese;Sushi Bars')
# ('Bean Juice', '4.5', '1014 19th St S', '16', 'Coffee & Tea;Sandwiches')
# ('Nutbush City Limits', '3.0', '3264 George St', '27', 'Bars;Breakfast & Brunch;American (Traditional)')
# ('Shenanigans Entertainment Center & Sports Bar', '2.5', '2100 Dawson Ave', '13', 'Arcades;Party & Event Planning;American (Traditional)')
# ('Rivoli Theatre & Pizzeria', '4.0', '117 4th St N', '35', 'Cinema;Pizza')
# ('Moxie’s', '3.0', '1835 Rose St', '4', 'American (New);Tiki Bars')
# ('Culina Mariana Cafe', '4.0', '5250 Justin Rd', '3', 'American (New);German;Breakfast & Brunch')
# ('Fiesta Mexicana', '4.0', '5200 Mormon Coulee Rd', '20', 'Mexican')
# ('Polito’s Pizza', '3.5', '116 3rd St S', '27', 'Pizza')
# ('Big Al’s Pizza', '3.0', '115 3rd St', '51', 'Pizza')
# ('Linda’s Bakery', '5.0', '190 E City Hwy 16', '18', 'Bakeries;Donuts;Gluten-Free')
# ('Gracie’s Gyros & Wraps', '3.0', '1908 Campbell Rd', '28', 'Bakeries;Greek')
# ('Big Boar Barbecue & Catering', '4.5', '510 Commerce Dr', '39', 'Barbeque')
# ('Angelini’s Ristorante', '3.5', '1427 State Hwy 35', '31', 'Italian;Pizza')
# ('Cabin Coffee', '4.0', '401 Jay St', '21', 'Coffee & Tea;Sandwiches')
# ('Two Beagles Brewpub', '3.0', '910 2nd Ave N', '36', 'American (New);Brewpubs')
# ('The Verse Lounge & Grill', '5.0', '717 Rose St', '1', 'Lounges;American (Traditional)')
# ('Kramer’s Bar & Grill', '4.0', '1123 3rd St S', '6', 'Restaurants')
# ('King Street Kitchen', '3.5', '141 7th St S', '7', 'American (Traditional);Breakfast & Brunch;Venues & Event Spaces')
# ('Dewey’s Side Street Saloon', '3.0', '621 Saint Paul St', '2', 'Bars;American (Traditional);Music Venues')
# ('Barre Country Diner', '4.0', 'W4007 Country Rd 0', '8', 'Diners;Breakfast & Brunch;Pizza')
# ('El Cerrito', '4.0', '306 Sand Lake Rd', '13', 'Mexican')
# ('4 Sisters 4th Street Bar and Catering', '3.5', '133 4th St S', '9', 'Wine Bars;Tapas Bars;Tapas/Small Plates')
# ('The Ridge', '4.0', 'W2782 State Rd 33', '5', 'Bars;American (Traditional)')
# ('Blue Moon Restaurant', '3.5', '716 2nd Ave N', '45', 'American (Traditional);Breakfast & Brunch')
# ('Sloopy’s Alma Mater', '3.5', '163 Copeland Ave', '8', 'Chicken Wings;Pizza;Sandwiches')
# ('Pla-Mor Lanes and The Eleventh Frame Diner', '5.0', '807 4th St S', '6', 'Bowling;Pizza;American (Traditional)')
# ('Famous Dave’s', '4.0', '3055 State Rd 16', '28', 'Barbeque;American (Traditional);Comfort Food')
# ('Hunan Chinese Restaurant & Lounge', '3.0', '318 4th St S', '20', 'Chinese')
# ('Marge’s On Rose', '3.0', '833 Rose St', '40', 'Breakfast & Brunch')
# ('Maggie’s On Main', '3.0', '205 Main St', '16', 'Breakfast & Brunch')
# ('Tequila Mexican Restaurant', '2.5', '515 West Ave N', '16', 'Mexican')
# ('Cabin Coffee La Crosse North', '5.0', '2843 Darling Ct', '2', 'Coffee & Tea;Breakfast & Brunch;Bagels')
# ('Quillin’s', '5.0', '24 S Walnut St', '1', 'Grocery;Delis')
# ('Lindy’s Subs & Salads', '3.5', '221 Main St', '23', 'Sandwiches;Salad')
# ('Burger Fusion Company', '2.5', '200 Pearl St', '18', 'Burgers;Ice Cream & Frozen Yogurt;Sandwiches')
# ('Alpine Inn', '3.5', 'W5717 Bliss Rd', '17', 'Bars;Burgers;American (Traditional)')
# ('The Barrel Bar & Grill', '4.0', '2005 West Ave S', '5', 'Sports Bars;American (Traditional)')
# ('QDOBA Mexican Eats', '3.5', '127 S 3rd St', '14', 'Mexican;Fast Food')
# ('Al’s State Road Pizzeria', '3.5', '2242 State Rd', '9', 'Pizza')
# ('Texas Roadhouse', '3.5', '4310 State Hwy 16', '34', 'Barbeque;Steakhouses')
# ('B.A. Burrito Co.', '3.0', '40 Copeland Ave', '26', 'Tex-Mex;Mexican')
# ('Pizza Doctors', '3.0', '624 King St', '34', 'Pizza;Buffets')
# ('Pettibone Boat Club', '2.5', 'S Pettibone Dr', '34', 'Burgers;American (Traditional);Sandwiches')
# ('Super Buffet', '2.0', '206 Copeland Ave', '9', 'Chinese;Buffets')
# ('Fox Hollow Golf Course', '5.0', 'N3287 County Trunk Oa', '5', 'Golf;Burgers;Venues & Event Spaces')
# ('Golden China', '4.5', '920 W City Hwy 16', '10', 'Chinese')
# ('CreekSide Grill and Pub', '4.0', 'W5450 Keil Coulee Rd', '4', 'Pubs;American (Traditional);Italian')
# ('Huhot Mongolian Grill', '3.5', '1501 Saint Andrew St', '24', 'Chinese;Asian Fusion;Mongolian')
# ('Boot Hill Pub', '3.5', '101 3rd St S', '7', 'Pubs;Burgers;Sandwiches')
# ('Bebo’s Dogs & Beef', '5.0', '311 Hampton Ct', '1', 'Hot Dogs')
# ('Outback Steakhouse', '3.0', '3039 Medco Ct', '28', 'Steakhouses')
# ('Castaways on the Island', '2.0', '131 Clinton St', '1', 'Restaurants')
# ('Olive Garden Italian Restaurant', '3.0', '9413 State Rd 16', '29', 'Italian;Salad')
# ('China Buffet', '2.5', '1611 Losey Blvd S', '14', 'Chinese')
# ('Manny’s Mexican Cocina', '3.5', '301 Hampton Ct', '87', 'Mexican')
# ('Domino’s Pizza', '4.5', '2402 State Rd', '5', 'Pizza;Chicken Wings;Sandwiches')
# ('Panera Bread', '3.0', '400 7th St N', '30', 'Sandwiches;Salad;Soup')
# ('Union Market', '4.0', '1411 Rose St', '1', 'Restaurants')
# ('Perkins Restaurant & Bakery', '2.5', 'N5914 County Rd Zz', '21', 'Bakeries;Breakfast & Brunch;American (Traditional)')
# ('Angry’s Way Out', '5.0', '315 West Avenue North', '1', 'Bars;American (Traditional);Chicken Wings')
# ('Taco Bell', '2.5', '325 West Avenue North', '6', 'Mexican;Tex-Mex;Fast Food')
# ('Señor Villa', '4.0', '325 West Ave N', '6', 'Mexican;Bars;Seafood')
# ('Coney Island Hot Dogs', '4.0', '1717 George St', '7', 'Hot Dogs')
# ('Toppers Pizza', '3.0', 'N5610 County Rd Ot', '5', 'Pizza')
# ('T-Jo’s Pizza', '3.0', '702 Main St', '12', 'Pizza;Sandwiches')
# ('Midway Deli', '4.0', '40 Copeland Ave', '8', 'Delis')
# ('Saxon Hall', '4.5', '1111 S Third St', '6', 'Pizza')
# ('Rocky Rococo - La Crosse', '2.5', '4202 Mormon Coulee Rd', '7', 'Pizza;Italian')
# ('Nell’s City Grill', '4.0', '205 Main St', '4', 'American (Traditional)')
# ('China Star', '2.5', '1205 La Crosse St', '24', 'Chinese')
# ('Mary Cody’s Restaurant and Maggie’s Lounge', '3.5', '101 Sky Harbour Dr', '16', 'American (New)')
# ('Subway', '4.0', '3132 Market Pl', '2', 'Sandwiches;Fast Food')
# ('Heroes Bar and Grill', '3.5', '1607 Losey Blvd S', '3', 'Bars;Sandwiches')
# ('Buffalo Wild Wings', '3.0', '312 Pearl St', '38', 'Chicken Wings;American (Traditional);Sports Bars')
# ('B.A. Burrito', '3.0', '835 Oak Ave S', '12', 'Mexican;Tex-Mex')
# ('Jimmy John’s', '3.0', '9432 State Rd 16', '15', 'Sandwiches;Delis;Fast Food')
# ('Culver’s', '4.5', '114 4th St S', '3', 'Burgers;Ice Cream & Frozen Yogurt;Fast Food')
# ('Burrachos Fresh Mexican Grill', '3.5', '9396 State Rd 16', '20', 'Mexican')
# ('Coney Island', '2.5', '988 12th Ave S', '7', 'Hot Dogs;Burgers')
# ('Subway', '4.0', '202 3rd St S', '4', 'Sandwiches;Fast Food')
# ('Cedar Creek', '4.0', '2600 Cedar Creek Ln', '1', 'Restaurants')
# ('Fazoli’s', '3.5', '9370 Hwy 16', '13', 'Italian')
# ('China Max', '4.0', 'Valley View Mall', '4', 'Chinese')
# ('McDonald’s', '4.5', '2437 W George St', '3', 'Coffee & Tea;Burgers;Fast Food')
# ('The Pizza Oven', '4.5', '920 W Hwy 16', '4', 'Pizza')
# ('Papa Murphy’s', '5.0', '1820 Jackson Street', '1', 'Pizza')
# ('Culver’s', '3.5', '4101 Mormon Coulee Rd', '10', 'Burgers;Ice Cream & Frozen Yogurt;Fast Food')
# ('Jim Dandy’s tasty eats & frozen treats', '4.5', '201 Hwy 16', '5', 'American (Traditional);Ice Cream & Frozen Yogurt')
# ('TGI Fridays', '2.5', '9416 Highway 16', '20', 'American (Traditional)')
# ('Red Lobster', '2.5', '3333 State Rd 16', '11', 'Seafood;American (Traditional)')
# ('The MOB Stop', '4.5', '208 S Holmen Dr', '6', 'Hot Dogs;Food Stands')
# ('Taco John’s', '2.5', '1211 Jackson St', '8', 'Mexican;Fast Food')
# ('Jimmy John’s', '4.5', '1420 Losey Blvd S', '3', 'Delis;Sandwiches;Fast Food')
# ('South Lanes Pizza and wings', '3.0', '1125 Main St', '5', 'Pizza;Bowling;Chicken Wings')
# ('Caribou Coffee', '4.0', '1202 County Rd Ph', '12', 'Bakeries;Coffee & Tea;Sandwiches')
# ('China Inn', '2.5', '9348 State Rd 16', '12', 'Chinese')
# ('Applebee’s Grill + Bar', '1.5', '9364 Hwy 16', '27', 'Sports Bars;Burgers;American (Traditional)')
# ('South Lanes Pizza', '2.5', '4107 Mormon Coulee Rd', '5', 'Pizza;Bowling;Bars')
# ('T.G.I. Friday’s', '4.0', '9430 State Rd 16', '6', 'American (New)')
# ('KFC', '3.0', '2001 Rose St', '5', 'Fast Food;Chicken Wings;Chicken Shop')
# ('Tequila’s Restaurant', '3.0', '425 2nd Ave S', '11', 'Mexican')
# ('A & W Family Restaurant', '2.5', '3005 South Ave', '10', 'Fast Food')
# ('Pizza Hut', '2.5', '2212 Rose St', '8', 'Pizza;Italian')
# ('Features Sports Bar & Grill', '3.0', '1425 State Hwy 16', '18', 'Bowling;Sports Bars;Burgers')
# ('Lindy’s Subs & Salads', '4.0', '225 Sand Lake Rd', '14', 'Salad;Fruits & Veggies')
# ('Culver’s', '3.5', '9422 State Rd 16', '5', 'Burgers;Fast Food;Ice Cream & Frozen Yogurt')
# ('Sidewalk Cafe', '3.5', '46 Main St', '3', 'Breakfast & Brunch;Burgers')
# ('Corky’s Pizza', '3.0', '25 S Walnut St', '10', 'Pizza;Ice Cream & Frozen Yogurt;Burgers')
# ('Big Al’s Too', '3.5', '103 10th Ave S', '3', 'Pizza')
# ('Pizza Corral', '4.0', '1505 S Holmen Dr', '20', 'Pizza')
# ('Dairy Queen', '3.5', '4200 Mormon Coulee Rd', '3', 'Fast Food;Ice Cream & Frozen Yogurt')
# ('Little Caesars Pizza', '1.5', '1022 La Crosse St', '3', 'Italian;Pizza')
# ('Arrowhead Tap House', '1.0', '2956 Airport Dr', '1', 'American (Traditional)')
# ('Toppers Pizza', '3.0', '605 2nd Ave S', '5', 'Pizza')
# ('Pizza Hut', '2.0', '2028 Ward Ave', '6', 'Pizza;Italian;Chicken Wings')
# ('Hunter’s Last Chance', '4.5', '150 S Leonard St', '4', 'Sports Bars;Burgers;Pizza')
# ('Rocky Rococo Pan Style Pizza', '3.0', '1239 Crossing Meadows Dr', '6', 'Pizza;Italian')
# ('Domino’s Pizza', '3.5', '224 Sand Lake Rd', '6', 'Pizza;Chicken Wings;Sandwiches')
# ('Mexican Tamales Restaurant', '2.5', '306 Sand Lake Rd', '12', 'Mexican')
# ('Hardee’s', '2.5', '1311 Rose St', '9', 'Fast Food')
# ('Jacqlons Cafe', '3.0', '512 S Main St', '4', 'Cafes')
# ('Westview Inn', '3.5', '174 Leonard St S', '6', 'American (New)')
# ('Chuck E Cheese’s', '3.5', '4444 State Rd 16', '4', 'Pizza;Arcades')
# ('Burger King', '1.0', '515 4th St N', '1', 'Restaurants')
# ('Perkins Restaurant & Bakery', '3.0', '9428 Highway 16', '16', 'Bakeries;Breakfast & Brunch;American (Traditional)')
# ('Rocky Rococo Pan Style Pizza', '2.5', '3800 State Rd 16', '2', 'Pizza')
# ('Wendy’s', '2.0', '4422 Mormon Coulee Rd', '3', 'Fast Food;Burgers')
# ('Taco John’s', '1.0', '602 Monitor St', '2', 'Fast Food;Mexican')
# ('The Bistro', '2.0', '500 Front St', '3', 'American (Traditional)')
# ('Ringside', '3.0', '223 Pearl St', '1', 'American (New)')
# ('Taco Bell', '3.5', '1243 Crossing Meadows Rd', '3', 'Tex-Mex;Fast Food;Mexican')
# ('Super Buffet Chinese Restaurant', '1.5', '9348 Highway 16', '3', 'Chinese')
# ('Papa Murphy’s', '2.5', '1220 Crossing Meadows Drive', '6', 'Pizza')
# ('Copper Penny', '3.0', '200 Main St', '1', 'Restaurants')
# ('Pizza Villa West Salem', '4.0', '156 Leonard St S', '2', 'Pizza')
# ('Dairy Queen', '2.0', '810 2nd Ave S', '9', 'Ice Cream & Frozen Yogurt;Fast Food')
# ('McDonald’s', '1.5', '2810 Losey Blvd S', '4', 'Fast Food;Burgers;Coffee & Tea')
# ('Arby’s', '3.0', '3210 N Kinney Coulee Rd', '2', 'Fast Food;Sandwiches')
# ('Burger King', '1.0', '3519 Mormon Coulee Rd', '3', 'Burgers;Fast Food')
# ('T Jo’s Pizza & Sandwich Shop', '4.5', '105 State St', '6', 'Pizza')
# ('Taco Bell', '1.0', '4141 Mormon Coulee Ct', '9', 'Mexican;Tex-Mex;Fast Food')
# ('Jimmy John’s', '3.0', '9432 State Rd 16', '7', 'Sandwiches;Delis;Fast Food')
# ('KFC', '1.5', '3415 Fiesta Ct', '4', 'Chicken Wings;Fast Food;Chicken Shop')
# ('Subway', '3.5', '9360 State Rd 16', '4', 'Sandwiches;Fast Food')
# ('Hearty Platter Cafe', '4.0', '42165 Csah 12', '1', 'Cafes;Travel Services')
# ('Primos Southwestern Grill', '1.5', '1427 Hwy 35', '5', 'American (Traditional);Mexican')
# ('Coney Island Hot Dogs', '3.0', '3800 Hwy 16', '6', 'Hot Dogs')
# ('Joe’s Bar & Grill At Days Inn', '1.0', '101 Sky Harbour Dr', '1', 'Bars;American (Traditional)')
# ('Subway', '1.0', '3810 Mormon Coulee Rd', '1', 'Sandwiches;Fast Food')
# ('Burger King', '1.5', '1124 George St W', '3', 'Restaurants')
# ('Wendy’s', '1.0', '9346 State Rd 16', '4', 'Burgers;Fast Food')
# ('American Legion Clubroom', '2.5', '509 N Chestnut St', '3', 'Restaurants')
# ('Subway', '3.0', '420 Commerce St', '2', 'Sandwiches;Fast Food')
# ('McDonald’s', '1.0', '9398 State Road 16', '1', 'Fast Food;Burgers;Coffee & Tea')
# ('Truckers Inn Restaurant', '2.0', 'I 90 & County 12', '1', 'Restaurants')
# ('Burger King', '1.5', '1259 Crossing Meadows Dr', '4', 'Sandwiches')
# ('Subway', '1.0', '301 Kistler Dr', '1', 'Sandwiches;Fast Food')

# %% [markdown]
# # <font color="red">TODO: Add a picture of converting a double `for` loop to a comprehension</font>

# %% [markdown]
# ## Looking at the type of `info`
#
# * `info` is a list of lists.
#     * Each call to `get_page_info` gives a list inside our main list.

# %%
# This is a list of lists, one list per url
[type(item) for item in info]
# Out:
# [list, list, list, list, list, list, list, list]

# %% [markdown]
# ### Step 3 - Flattening the results
#
# * We will use 2 `for` clauses to flatten the output
#     * first/outer `for` processes out list
#     * second/inner `for` processes a row of data

# %%
flat_info = [row for info_list in info for row in info_list]
[row for row in flat_info][:5]
# Out:
# [('The Waterfront Restaurant & Tavern',
#   '4.5',
#   '328 Front St S',
#   '182',
#   'American (New);Seafood;Steakhouses'),
#  ('Buzzard Billy’s',
#   '4.0',
#   '222 Pearl St',
#   '203',
#   'American (Traditional);Cajun/Creole'),
#  ('Greengrass Cafe',
#   '4.0',
#   '1904 Campbell Rd',
#   '85',
#   'Breakfast & Brunch;Bars'),
#  ('Lovechild Restaurant',
#   '4.5',
#   '300 3rd St S',
#   '75',
#   'Salad;Bars;Steakhouses'),
#  ('The Charmant', '4.5', '101 State St', '125', 'French;American (New)')]

# %% [markdown]
# ## Writing the output to a file.
#
# * Turn each row of data into a comma separated string.
# * Use a `with` statement to open a file.
# * Use `print` and a `for` loop to write the output.

# %%
lines = [','.join(row) for row in flat_info]
lines[:10]
# Out:
# ['The Waterfront Restaurant & Tavern,4.5,328 Front St S,182,American (New);Seafood;Steakhouses',
#  'Buzzard Billy’s,4.0,222 Pearl St,203,American (Traditional);Cajun/Creole',
#  'Greengrass Cafe,4.0,1904 Campbell Rd,85,Breakfast & Brunch;Bars',
#  'Lovechild Restaurant,4.5,300 3rd St S,75,Salad;Bars;Steakhouses',
#  'The Charmant,4.5,101 State St,125,French;American (New)',
#  'The Root Note,4.5,115 4th St S,65,Music Venues;Coffee & Tea;Creperies',
#  'Piggy’s Restaurant,4.0,501 Front St S,109,Steakhouses;Seafood;Sandwiches',
#  'Howie’s on La Crosse,4.0,1128 La Crosse St,50,American (New);Pubs',
#  'Kate’s On State,4.0,333 Main St,78,Italian;Seafood',
#  'The Freighthouse Restaurant,4.0,107 Vine St,103,Seafood;Steakhouses;Desserts']

# %% [markdown]
# ### Step 4 - Write to a file

# %%
with open('lunch.csv', 'w') as out_file:
    for line in lines:
        print(line, file = out_file)

# %%
# Mac command
# %cat lunch.csv
# Out:
# The Waterfront Restaurant & Tavern,4.5,328 Front St S,182,American (New);Seafood;Steakhouses
# Buzzard Billy’s,4.0,222 Pearl St,203,Breakfast & Brunch;Bars
# The Charmant,4.5,101 State St,124,American (Traditional);Cajun/Creole
# Lovechild Restaurant,4.5,300 3rd St S,75,French;American (New)
# Piggy’s Restaurant,4.0,501 Front St S,108,Salad;Bars;Steakhouses
# Greengrass Cafe,4.0,1904 Campbell Rd,85,Music Venues;Coffee & Tea;Creperies
# Dublin Square Irish Pub & Eatery,4.0,103 3rd St N,173,Steakhouses;Seafood;Sandwiches
# The Root Note,4.5,115 4th St S,65,American (New);Pubs
# The Freighthouse Restaurant,4.0,107 Vine St,103,American (Traditional);Irish Pub
# The Crow,3.5,100 3rd St S,104,Italian;Seafood
# Howie’s on La Crosse,4.0,1128 La Crosse St,50,Seafood;Steakhouses;Desserts
# Kate’s On State,4.0,333 Main St,78,American (Traditional);Breakfast & Brunch;Pubs
# Le Chateau,4.5,410 Cass St,46,Diners;Cafes;American (Traditional)
# Digger’s Sting Restaurant,4.0,122 3rd St N,50,American (Traditional);Breakfast & Brunch
# Iguana’s Mexican Street Café,4.0,1800 State St,66,Bakeries;American (Traditional);Pubs
# Hmong’s Golden Egg Roll,4.0,901 State St,53,French;Wine Bars;Cocktail Bars
# Burger Fusion Company,4.0,324 Jay St,45,American (New);Steakhouses
# Stein Haus,4.0,327 Jay St,32,American (Traditional);Steakhouses;Seafood
# Pickerman’s Soup & Sandwiches,4.5,135 S 4th St,45,Thai;Delis
# Fayze’s,3.5,146 Rose St,117,German;Pubs
# Press Break,5.0,214 Main St,7,American (Traditional);Salad;Gastropubs
# David Reay’s Modern Diner + Tavern,4.0,2225 16th St S,61,American (Traditional);Seafood
# Rosie’s Cafe,4.5,W7305 County Rd Z,35,Mexican
# Red Pines Bar & Grill,4.5,3429 Mormon Coulee Rd,64,Bakeries;Cafes;Breakfast & Brunch
# Hungry Peddler,4.0,1205 La Crosse St,46,Mexican
# Burritos House,4.5,1203 La Crosse St,31,Laotian;Vietnamese;Thai
# Thao’s Thai Restaurant and Deli,3.5,325 West Ave N,18,Chicken Wings;American (Traditional);Burgers
# Señor Villa,4.0,3800 WI-16,44,Sandwiches;Soup;Hot Dogs
# Nosh,5.0,100 Harborview Plz,5,Sandwiches;Soup
# Howie’s on La Crosse,4.0,1128 La Crosse St,50,American (New);Seafood;Steakhouses
# Kate’s On State,4.0,333 Main St,78,Breakfast & Brunch;Bars
# Le Chateau,4.5,410 Cass St,46,American (Traditional);Cajun/Creole
# Digger’s Sting Restaurant,4.0,122 3rd St N,50,French;American (New)
# Iguana’s Mexican Street Café,4.0,1800 State St,66,Salad;Bars;Steakhouses
# Hmong’s Golden Egg Roll,4.0,901 State St,53,Music Venues;Coffee & Tea;Creperies
# Burger Fusion Company,4.0,324 Jay St,45,Steakhouses;Seafood;Sandwiches
# Stein Haus,4.0,327 Jay St,32,American (New);Pubs
# Pickerman’s Soup & Sandwiches,4.5,135 S 4th St,45,American (Traditional);Irish Pub
# Fayze’s,3.5,146 Rose St,117,Italian;Seafood
# Press Break,5.0,214 Main St,7,Seafood;Steakhouses;Desserts
# David Reay’s Modern Diner + Tavern,4.0,2225 16th St S,61,American (Traditional);Breakfast & Brunch;Pubs
# Rosie’s Cafe,4.5,W7305 County Rd Z,35,Diners;Cafes;American (Traditional)
# Red Pines Bar & Grill,4.5,3429 Mormon Coulee Rd,64,American (Traditional);Breakfast & Brunch
# Hungry Peddler,4.0,1205 La Crosse St,46,Bakeries;American (Traditional);Pubs
# Burritos House,4.5,1203 La Crosse St,31,French;Wine Bars;Cocktail Bars
# Thao’s Thai Restaurant and Deli,3.5,325 West Ave N,18,American (New);Steakhouses
# Señor Villa,4.0,3800 WI-16,44,American (Traditional);Steakhouses;Seafood
# Nosh,5.0,100 Harborview Plz,5,Thai;Delis
# 4 Sisters Wine Bar and Tapas,3.5,2120 Rose St,93,German;Pubs
# La Crosse Family Restaurant,4.0,1311 La Crescent Pl,51,American (Traditional);Salad;Gastropubs
# River Rats Bar and Grill,4.5,212 Main St NE,14,American (Traditional);Seafood
# Pizza Amoré,4.0,214 Main St,66,Mexican
# The Breakfast Club and Pub,3.5,W4516 Eddie Ave,81,Bakeries;Cafes;Breakfast & Brunch
# Timmers 10 Mile Pub,4.5,1217 Caledonia St,11,Mexican
# Uptowne Cafe & Bakery,4.0,129 Marina Dr,26,Laotian;Vietnamese;Thai
# Huck Finn’s On the Water,3.0,444 N Chestnut St,39,Chicken Wings;American (Traditional);Burgers
# Schmitty’s TimeOut Tavern,5.0,1812 Jackson St,4,Sandwiches;Soup;Hot Dogs
# New Taste of India,4.0,1004 La Crosse St,96,Sandwiches;Soup
# Press Break,5.0,146 Rose St,7,American (New);Seafood;Steakhouses
# David Reay’s Modern Diner + Tavern,4.0,214 Main St,61,Breakfast & Brunch;Bars
# Rosie’s Cafe,4.5,2225 16th St S,35,American (Traditional);Cajun/Creole
# Red Pines Bar & Grill,4.5,W7305 County Rd Z,64,French;American (New)
# Hungry Peddler,4.0,3429 Mormon Coulee Rd,46,Salad;Bars;Steakhouses
# Burritos House,4.5,1205 La Crosse St,31,Music Venues;Coffee & Tea;Creperies
# Thao’s Thai Restaurant and Deli,3.5,1203 La Crosse St,18,Steakhouses;Seafood;Sandwiches
# Señor Villa,4.0,325 West Ave N,44,American (New);Pubs
# Nosh,5.0,3800 WI-16,5,American (Traditional);Irish Pub
# 4 Sisters Wine Bar and Tapas,3.5,100 Harborview Plz,93,Italian;Seafood
# La Crosse Family Restaurant,4.0,2120 Rose St,51,Seafood;Steakhouses;Desserts
# River Rats Bar and Grill,4.5,1311 La Crescent Pl,14,American (Traditional);Breakfast & Brunch;Pubs
# Pizza Amoré,4.0,212 Main St NE,66,Diners;Cafes;American (Traditional)
# The Breakfast Club and Pub,3.5,214 Main St,81,American (Traditional);Breakfast & Brunch
# Timmers 10 Mile Pub,4.5,W4516 Eddie Ave,11,Bakeries;American (Traditional);Pubs
# Uptowne Cafe & Bakery,4.0,1217 Caledonia St,26,French;Wine Bars;Cocktail Bars
# Huck Finn’s On the Water,3.0,129 Marina Dr,39,American (New);Steakhouses
# Schmitty’s TimeOut Tavern,5.0,444 N Chestnut St,4,American (Traditional);Steakhouses;Seafood
# New Taste of India,4.0,1812 Jackson St,96,Thai;Delis
# Rudy’s Drive-In,4.5,1004 La Crosse St,37,German;Pubs
# Big Mama’s Gyros,5.0,Dave's Guitar Shop Parking Lot,9,American (Traditional);Salad;Gastropubs
# Dim Sum Tea Shop,4.0,221 Pearl St,36,American (Traditional);Seafood
# North Country Steak Buffet,4.0,2526 Rose St,24,Mexican
# Kaddy’s Kafe,4.5,236 E Main St,16,Bakeries;Cafes;Breakfast & Brunch
# Ciatti’s Italian Grill,4.5,2846 Midwest Dr,39,Mexican
# Sushi Pirate,3.5,200 Main St,43,Laotian;Vietnamese;Thai
# Ye Old Style Inn,4.5,828 5th Ave S,4,Chicken Wings;American (Traditional);Burgers
# Taste of Thai,4.0,205 S Holmen Dr,25,Sandwiches;Soup;Hot Dogs
# El Rodeo Restaurant,4.0,115 5th Ave S,20,Sandwiches;Soup
# Houghton’s Jackson Street Pub,3.5,1002 Jackson St,24,Burgers;American (Traditional)
# La Crosse Family Restaurant,4.0,2120 Rose St,51,American (New);Seafood;Steakhouses
# River Rats Bar and Grill,4.5,1311 La Crescent Pl,14,Breakfast & Brunch;Bars
# Pizza Amoré,4.0,212 Main St NE,66,American (Traditional);Cajun/Creole
# The Breakfast Club and Pub,3.5,214 Main St,81,French;American (New)
# Timmers 10 Mile Pub,4.5,W4516 Eddie Ave,11,Salad;Bars;Steakhouses
# Uptowne Cafe & Bakery,4.0,1217 Caledonia St,26,Music Venues;Coffee & Tea;Creperies
# Huck Finn’s On the Water,3.0,129 Marina Dr,39,Steakhouses;Seafood;Sandwiches
# Schmitty’s TimeOut Tavern,5.0,444 N Chestnut St,4,American (New);Pubs
# New Taste of India,4.0,1812 Jackson St,96,American (Traditional);Irish Pub
# Rudy’s Drive-In,4.5,1004 La Crosse St,37,Italian;Seafood
# Big Mama’s Gyros,5.0,Dave's Guitar Shop Parking Lot,9,Seafood;Steakhouses;Desserts
# Dim Sum Tea Shop,4.0,221 Pearl St,36,American (Traditional);Breakfast & Brunch;Pubs
# North Country Steak Buffet,4.0,2526 Rose St,24,Diners;Cafes;American (Traditional)
# Kaddy’s Kafe,4.5,236 E Main St,16,American (Traditional);Breakfast & Brunch
# Ciatti’s Italian Grill,4.5,2846 Midwest Dr,39,Bakeries;American (Traditional);Pubs
# Sushi Pirate,3.5,200 Main St,43,French;Wine Bars;Cocktail Bars
# Ye Old Style Inn,4.5,828 5th Ave S,4,American (New);Steakhouses
# Taste of Thai,4.0,205 S Holmen Dr,25,American (Traditional);Steakhouses;Seafood
# El Rodeo Restaurant,4.0,115 5th Ave S,20,Thai;Delis
# Houghton’s Jackson Street Pub,3.5,1002 Jackson St,24,German;Pubs
# Three Rivers Lodge River View Restaurant and Bar,3.5,111 Front St S,22,American (Traditional);Salad;Gastropubs
# The Twisted Moose,2.5,128 3rd St S,25,American (Traditional);Seafood
# Royal Indian Cuisine,4.5,235 Sand Lake Rd,56,Mexican
# Pogreba Restaurant,3.5,1232 Avon St,36,Bakeries;Cafes;Breakfast & Brunch
# Great Harvest Bread Company,4.5,58 Copeland Ave,5,Mexican
# Schmidty’s Bar & Restaurant,4.0,3119 State Rd,15,Laotian;Vietnamese;Thai
# Fox Hollow Sports Bar,4.5,N3287 County Rd OA,10,Chicken Wings;American (Traditional);Burgers
# JavaVino,4.0,2311 State Rd,29,Sandwiches;Soup;Hot Dogs
# Great Wall,3.5,322 Main St,22,Sandwiches;Soup
# Shogun Sushi And Hibachi,4.0,1227 Crossing Meadows Dr,52,Burgers;American (Traditional)
# Big Mama’s Gyros,5.0,Dave's Guitar Shop Parking Lot,9,American (New);Seafood;Steakhouses
# Dim Sum Tea Shop,4.0,221 Pearl St,36,Breakfast & Brunch;Bars
# North Country Steak Buffet,4.0,2526 Rose St,24,American (Traditional);Cajun/Creole
# Kaddy’s Kafe,4.5,236 E Main St,16,French;American (New)
# Ciatti’s Italian Grill,4.5,2846 Midwest Dr,39,Salad;Bars;Steakhouses
# Sushi Pirate,3.5,200 Main St,43,Music Venues;Coffee & Tea;Creperies
# Ye Old Style Inn,4.5,828 5th Ave S,4,Steakhouses;Seafood;Sandwiches
# Taste of Thai,4.0,205 S Holmen Dr,25,American (New);Pubs
# El Rodeo Restaurant,4.0,115 5th Ave S,20,American (Traditional);Irish Pub
# Houghton’s Jackson Street Pub,3.5,1002 Jackson St,24,Italian;Seafood
# Three Rivers Lodge River View Restaurant and Bar,3.5,111 Front St S,22,Seafood;Steakhouses;Desserts
# The Twisted Moose,2.5,128 3rd St S,25,American (Traditional);Breakfast & Brunch;Pubs
# Royal Indian Cuisine,4.5,235 Sand Lake Rd,56,Diners;Cafes;American (Traditional)
# Pogreba Restaurant,3.5,1232 Avon St,36,American (Traditional);Breakfast & Brunch
# Great Harvest Bread Company,4.5,58 Copeland Ave,5,Bakeries;American (Traditional);Pubs
# Schmidty’s Bar & Restaurant,4.0,3119 State Rd,15,French;Wine Bars;Cocktail Bars
# Fox Hollow Sports Bar,4.5,N3287 County Rd OA,10,American (New);Steakhouses
# JavaVino,4.0,2311 State Rd,29,American (Traditional);Steakhouses;Seafood
# Great Wall,3.5,322 Main St,22,Thai;Delis
# Shogun Sushi And Hibachi,4.0,1227 Crossing Meadows Dr,52,German;Pubs
# Ardie’s Restaurant / Flipside Pub & Grill,3.5,400 Lang Dr,25,American (Traditional);Salad;Gastropubs
# Famous Dave’s,4.0,3055 State Rd 16,29,American (Traditional);Seafood
# Eagle’s Nest Sports Bar & Grill,3.5,1914 Campbell Rd,15,Mexican
# Linda’s Bakery,5.0,190 E City Hwy 16,18,Bakeries;Cafes;Breakfast & Brunch
# Marco’s Pizza,4.5,3514 Mormon Coulee Rd,7,Mexican
# Tom Sawyer’s Bar & Grill,3.5,136 Clinton St,23,Laotian;Vietnamese;Thai
# Fiesta Mexicana,4.0,5200 Mormon Coulee Rd,20,Chicken Wings;American (Traditional);Burgers
# Arterial,3.5,1003 16th St S,15,Sandwiches;Soup;Hot Dogs
# The Ridge,4.0,W2782 State Rd 33,5,Sandwiches;Soup
# Shenanigans Entertainment Center & Sports Bar,2.5,2100 Dawson Ave,13,Burgers;American (Traditional)
# Three Rivers Lodge River View Restaurant and Bar,3.5,111 Front St S,22,American (New);Seafood;Steakhouses
# The Twisted Moose,2.5,128 3rd St S,25,Breakfast & Brunch;Bars
# Royal Indian Cuisine,4.5,235 Sand Lake Rd,56,American (Traditional);Cajun/Creole
# Pogreba Restaurant,3.5,1232 Avon St,36,French;American (New)
# Great Harvest Bread Company,4.5,58 Copeland Ave,5,Salad;Bars;Steakhouses
# Schmidty’s Bar & Restaurant,4.0,3119 State Rd,15,Music Venues;Coffee & Tea;Creperies
# Fox Hollow Sports Bar,4.5,N3287 County Rd OA,10,Steakhouses;Seafood;Sandwiches
# JavaVino,4.0,2311 State Rd,29,American (New);Pubs
# Great Wall,3.5,322 Main St,22,American (Traditional);Irish Pub
# Shogun Sushi And Hibachi,4.0,1227 Crossing Meadows Dr,52,Italian;Seafood
# Ardie’s Restaurant / Flipside Pub & Grill,3.5,400 Lang Dr,25,Seafood;Steakhouses;Desserts
# Famous Dave’s,4.0,3055 State Rd 16,29,American (Traditional);Breakfast & Brunch;Pubs
# Eagle’s Nest Sports Bar & Grill,3.5,1914 Campbell Rd,15,Diners;Cafes;American (Traditional)
# Linda’s Bakery,5.0,190 E City Hwy 16,18,American (Traditional);Breakfast & Brunch
# Marco’s Pizza,4.5,3514 Mormon Coulee Rd,7,Bakeries;American (Traditional);Pubs
# Tom Sawyer’s Bar & Grill,3.5,136 Clinton St,23,French;Wine Bars;Cocktail Bars
# Fiesta Mexicana,4.0,5200 Mormon Coulee Rd,20,American (New);Steakhouses
# Arterial,3.5,1003 16th St S,15,American (Traditional);Steakhouses;Seafood
# The Ridge,4.0,W2782 State Rd 33,5,Thai;Delis
# Shenanigans Entertainment Center & Sports Bar,2.5,2100 Dawson Ave,13,German;Pubs
# Big Boar Barbecue & Catering,4.5,510 Commerce Dr,39,American (Traditional);Salad;Gastropubs
# Bean Juice,4.5,1014 19th St S,16,American (Traditional);Seafood
# El Cerrito,4.0,306 Sand Lake Rd,13,Mexican
# Nutbush City Limits,3.0,3264 George St,27,Bakeries;Cafes;Breakfast & Brunch
# Two Beagles Brewpub,3.0,910 2nd Ave N,36,Mexican
# Hackberry’s Bistro,3.5,315 5th Ave S,32,Laotian;Vietnamese;Thai
# Big Al’s Pizza,3.0,115 3rd St,51,Chicken Wings;American (Traditional);Burgers
# Culina Mariana Cafe,4.0,5250 Justin Rd,3,Sandwiches;Soup;Hot Dogs
# Pizza King-Pizza Subs Gyros,4.5,2929 S Ave,12,Sandwiches;Soup
# Angelini’s Ristorante,3.5,1427 State Hwy 35,31,Burgers;American (Traditional)
# Ardie’s Restaurant / Flipside Pub & Grill,3.5,400 Lang Dr,25,American (New);Seafood;Steakhouses
# Famous Dave’s,4.0,3055 State Rd 16,29,Breakfast & Brunch;Bars
# Eagle’s Nest Sports Bar & Grill,3.5,1914 Campbell Rd,15,American (Traditional);Cajun/Creole
# Linda’s Bakery,5.0,190 E City Hwy 16,18,French;American (New)
# Marco’s Pizza,4.5,3514 Mormon Coulee Rd,7,Salad;Bars;Steakhouses
# Tom Sawyer’s Bar & Grill,3.5,136 Clinton St,23,Music Venues;Coffee & Tea;Creperies
# Fiesta Mexicana,4.0,5200 Mormon Coulee Rd,20,Steakhouses;Seafood;Sandwiches
# Arterial,3.5,1003 16th St S,15,American (New);Pubs
# The Ridge,4.0,W2782 State Rd 33,5,American (Traditional);Irish Pub
# Shenanigans Entertainment Center & Sports Bar,2.5,2100 Dawson Ave,13,Italian;Seafood
# Big Boar Barbecue & Catering,4.5,510 Commerce Dr,39,Seafood;Steakhouses;Desserts
# Bean Juice,4.5,1014 19th St S,16,American (Traditional);Breakfast & Brunch;Pubs
# El Cerrito,4.0,306 Sand Lake Rd,13,Diners;Cafes;American (Traditional)
# Nutbush City Limits,3.0,3264 George St,27,American (Traditional);Breakfast & Brunch
# Two Beagles Brewpub,3.0,910 2nd Ave N,36,Bakeries;American (Traditional);Pubs
# Hackberry’s Bistro,3.5,315 5th Ave S,32,French;Wine Bars;Cocktail Bars
# Big Al’s Pizza,3.0,115 3rd St,51,American (New);Steakhouses
# Culina Mariana Cafe,4.0,5250 Justin Rd,3,American (Traditional);Steakhouses;Seafood
# Pizza King-Pizza Subs Gyros,4.5,2929 S Ave,12,Thai;Delis
# Angelini’s Ristorante,3.5,1427 State Hwy 35,31,German;Pubs
# Blue Moon Restaurant,3.5,716 2nd Ave N,45,American (Traditional);Salad;Gastropubs
# River Rocks Coffee,4.0,332 Front St S,4,American (Traditional);Seafood
# Pettibone Boat Club,2.5,S Pettibone Dr,34,Mexican
# Texas Roadhouse,3.5,4310 State Hwy 16,34,Bakeries;Cafes;Breakfast & Brunch
# The Verse Lounge & Grill,5.0,717 Rose St,1,Mexican
# Hunan Chinese Restaurant & Lounge,3.0,318 4th St S,20,Laotian;Vietnamese;Thai
# Rivoli Theatre & Pizzeria,4.0,117 4th St N,35,Chicken Wings;American (Traditional);Burgers
# Burger Fusion Company,2.5,200 Pearl St,18,Sandwiches;Soup;Hot Dogs
# Gracie’s Gyros & Wraps,3.0,1908 Campbell Rd,28,Sandwiches;Soup
# Sloopy’s Alma Mater,3.5,163 Copeland Ave,8,Burgers;American (Traditional)
# Big Boar Barbecue & Catering,4.5,510 Commerce Dr,39,American (New);Seafood;Steakhouses
# Bean Juice,4.5,1014 19th St S,16,Breakfast & Brunch;Bars
# El Cerrito,4.0,306 Sand Lake Rd,13,American (Traditional);Cajun/Creole
# Nutbush City Limits,3.0,3264 George St,27,French;American (New)
# Two Beagles Brewpub,3.0,910 2nd Ave N,36,Salad;Bars;Steakhouses
# Hackberry’s Bistro,3.5,315 5th Ave S,32,Music Venues;Coffee & Tea;Creperies
# Big Al’s Pizza,3.0,115 3rd St,51,Steakhouses;Seafood;Sandwiches
# Culina Mariana Cafe,4.0,5250 Justin Rd,3,American (New);Pubs
# Pizza King-Pizza Subs Gyros,4.5,2929 S Ave,12,American (Traditional);Irish Pub
# Angelini’s Ristorante,3.5,1427 State Hwy 35,31,Italian;Seafood
# Blue Moon Restaurant,3.5,716 2nd Ave N,45,Seafood;Steakhouses;Desserts
# River Rocks Coffee,4.0,332 Front St S,4,American (Traditional);Breakfast & Brunch;Pubs
# Pettibone Boat Club,2.5,S Pettibone Dr,34,Diners;Cafes;American (Traditional)
# Texas Roadhouse,3.5,4310 State Hwy 16,34,American (Traditional);Breakfast & Brunch
# The Verse Lounge & Grill,5.0,717 Rose St,1,Bakeries;American (Traditional);Pubs
# Hunan Chinese Restaurant & Lounge,3.0,318 4th St S,20,French;Wine Bars;Cocktail Bars
# Rivoli Theatre & Pizzeria,4.0,117 4th St N,35,American (New);Steakhouses
# Burger Fusion Company,2.5,200 Pearl St,18,American (Traditional);Steakhouses;Seafood
# Gracie’s Gyros & Wraps,3.0,1908 Campbell Rd,28,Thai;Delis
# Sloopy’s Alma Mater,3.5,163 Copeland Ave,8,German;Pubs
# Huhot Mongolian Grill,3.5,3039 Medco Ct,24,American (Traditional);Salad;Gastropubs
# Grizzly’s,3.0,221 Main St,38,American (Traditional);Seafood
# Lindy’s Subs & Salads,3.5,W5717 Bliss Rd,23,Mexican
# Alpine Inn,3.5,920 W City Hwy 16,17,Bakeries;Cafes;Breakfast & Brunch
# Golden China,4.5,116 3rd St S,10,Mexican
# Polito’s Pizza,3.5,621 Saint Paul St,27,Laotian;Vietnamese;Thai
# Dewey’s Side Street Saloon,3.0,133 4th St S,2,Chicken Wings;American (Traditional);Burgers
# 4 Sisters 4th Street Bar and Catering,3.5,N3287 County Trunk Oa,9,Sandwiches;Soup;Hot Dogs
# Fox Hollow Golf Course,5.0,401 Jay St,5,Sandwiches;Soup
# Blue Moon Restaurant,3.5,716 2nd Ave N,45,American (New);Seafood;Steakhouses
# River Rocks Coffee,4.0,332 Front St S,4,Breakfast & Brunch;Bars
# Pettibone Boat Club,2.5,S Pettibone Dr,34,American (Traditional);Cajun/Creole
# Texas Roadhouse,3.5,4310 State Hwy 16,34,French;American (New)
# The Verse Lounge & Grill,5.0,717 Rose St,1,Salad;Bars;Steakhouses
# Hunan Chinese Restaurant & Lounge,3.0,318 4th St S,20,Music Venues;Coffee & Tea;Creperies
# Rivoli Theatre & Pizzeria,4.0,117 4th St N,35,Steakhouses;Seafood;Sandwiches
# Burger Fusion Company,2.5,200 Pearl St,18,American (New);Pubs
# Gracie’s Gyros & Wraps,3.0,1908 Campbell Rd,28,American (Traditional);Irish Pub
# Sloopy’s Alma Mater,3.5,163 Copeland Ave,8,Italian;Seafood
# Huhot Mongolian Grill,3.5,3039 Medco Ct,24,Seafood;Steakhouses;Desserts
# Grizzly’s,3.0,221 Main St,38,American (Traditional);Breakfast & Brunch;Pubs
# Lindy’s Subs & Salads,3.5,W5717 Bliss Rd,23,Diners;Cafes;American (Traditional)
# Alpine Inn,3.5,920 W City Hwy 16,17,American (Traditional);Breakfast & Brunch
# Golden China,4.5,116 3rd St S,10,Bakeries;American (Traditional);Pubs
# Polito’s Pizza,3.5,621 Saint Paul St,27,French;Wine Bars;Cocktail Bars
# Dewey’s Side Street Saloon,3.0,133 4th St S,2,American (New);Steakhouses
# 4 Sisters 4th Street Bar and Catering,3.5,N3287 County Trunk Oa,9,American (Traditional);Steakhouses;Seafood
# Fox Hollow Golf Course,5.0,401 Jay St,5,Thai;Delis
# Cabin Coffee,4.0,24 S Walnut St,21,German;Pubs
# Quillin’s,5.0,301 Hampton Ct,1,American (Traditional);Salad;Gastropubs
# Manny’s Mexican Cocina,3.5,2005 West Ave S,87,American (Traditional);Seafood
# The Barrel Bar & Grill,4.0,807 4th St S,5,Mexican
# Pla-Mor Lanes and The Eleventh Frame Diner,5.0,1123 3rd St S,6,Bakeries;Cafes;Breakfast & Brunch
# Kramer’s Bar & Grill,4.0,127 S 3rd St,6,Mexican
# QDOBA Mexican Eats,3.5,2843 Darling Ct,14,Laotian;Vietnamese;Thai
# Cabin Coffee La Crosse North,5.0,40 Copeland Ave,2,Chicken Wings;American (Traditional);Burgers
# B.A. Burrito Co.,3.0,205 Main St,25,Sandwiches;Soup;Hot Dogs
# Maggie’s On Main,3.0,1835 Rose St,16,Sandwiches;Soup

# %%
# PC command
# !type lunch.csv
# Out:
# The Waterfront Restaurant & Tavern,4.5,328 Front St S,182,American (New);Seafood;Steakhouses
# Buzzard Billy’s,4.0,222 Pearl St,203,Breakfast & Brunch;Bars
# The Charmant,4.5,101 State St,124,American (Traditional);Cajun/Creole
# Lovechild Restaurant,4.5,300 3rd St S,75,French;American (New)
# Piggy’s Restaurant,4.0,501 Front St S,108,Salad;Bars;Steakhouses
# Greengrass Cafe,4.0,1904 Campbell Rd,85,Music Venues;Coffee & Tea;Creperies
# Dublin Square Irish Pub & Eatery,4.0,103 3rd St N,173,Steakhouses;Seafood;Sandwiches
# The Root Note,4.5,115 4th St S,65,American (New);Pubs
# The Freighthouse Restaurant,4.0,107 Vine St,103,American (Traditional);Irish Pub
# The Crow,3.5,100 3rd St S,104,Italian;Seafood
# Howie’s on La Crosse,4.0,1128 La Crosse St,50,Seafood;Steakhouses;Desserts
# Kate’s On State,4.0,333 Main St,78,American (Traditional);Breakfast & Brunch;Pubs
# Le Chateau,4.5,410 Cass St,46,Diners;Cafes;American (Traditional)
# Digger’s Sting Restaurant,4.0,122 3rd St N,50,American (Traditional);Breakfast & Brunch
# Iguana’s Mexican Street Café,4.0,1800 State St,66,Bakeries;American (Traditional);Pubs
# Hmong’s Golden Egg Roll,4.0,901 State St,53,French;Wine Bars;Cocktail Bars
# Burger Fusion Company,4.0,324 Jay St,45,American (New);Steakhouses
# Stein Haus,4.0,327 Jay St,32,American (Traditional);Steakhouses;Seafood
# Pickerman’s Soup & Sandwiches,4.5,135 S 4th St,45,Thai;Delis
# Fayze’s,3.5,146 Rose St,117,German;Pubs
# Press Break,5.0,214 Main St,7,American (Traditional);Salad;Gastropubs
# David Reay’s Modern Diner + Tavern,4.0,2225 16th St S,61,American (Traditional);Seafood
# Rosie’s Cafe,4.5,W7305 County Rd Z,35,Mexican
# Red Pines Bar & Grill,4.5,3429 Mormon Coulee Rd,64,Bakeries;Cafes;Breakfast & Brunch
# Hungry Peddler,4.0,1205 La Crosse St,46,Mexican
# Burritos House,4.5,1203 La Crosse St,31,Laotian;Vietnamese;Thai
# Thao’s Thai Restaurant and Deli,3.5,325 West Ave N,18,Chicken Wings;American (Traditional);Burgers
# Señor Villa,4.0,3800 WI-16,44,Sandwiches;Soup;Hot Dogs
# Nosh,5.0,100 Harborview Plz,5,Sandwiches;Soup
# Howie’s on La Crosse,4.0,1128 La Crosse St,50,American (New);Seafood;Steakhouses
# Kate’s On State,4.0,333 Main St,78,Breakfast & Brunch;Bars
# Le Chateau,4.5,410 Cass St,46,American (Traditional);Cajun/Creole
# Digger’s Sting Restaurant,4.0,122 3rd St N,50,French;American (New)
# Iguana’s Mexican Street Café,4.0,1800 State St,66,Salad;Bars;Steakhouses
# Hmong’s Golden Egg Roll,4.0,901 State St,53,Music Venues;Coffee & Tea;Creperies
# Burger Fusion Company,4.0,324 Jay St,45,Steakhouses;Seafood;Sandwiches
# Stein Haus,4.0,327 Jay St,32,American (New);Pubs
# Pickerman’s Soup & Sandwiches,4.5,135 S 4th St,45,American (Traditional);Irish Pub
# Fayze’s,3.5,146 Rose St,117,Italian;Seafood
# Press Break,5.0,214 Main St,7,Seafood;Steakhouses;Desserts
# David Reay’s Modern Diner + Tavern,4.0,2225 16th St S,61,American (Traditional);Breakfast & Brunch;Pubs
# Rosie’s Cafe,4.5,W7305 County Rd Z,35,Diners;Cafes;American (Traditional)
# Red Pines Bar & Grill,4.5,3429 Mormon Coulee Rd,64,American (Traditional);Breakfast & Brunch
# Hungry Peddler,4.0,1205 La Crosse St,46,Bakeries;American (Traditional);Pubs
# Burritos House,4.5,1203 La Crosse St,31,French;Wine Bars;Cocktail Bars
# Thao’s Thai Restaurant and Deli,3.5,325 West Ave N,18,American (New);Steakhouses
# Señor Villa,4.0,3800 WI-16,44,American (Traditional);Steakhouses;Seafood
# Nosh,5.0,100 Harborview Plz,5,Thai;Delis
# 4 Sisters Wine Bar and Tapas,3.5,2120 Rose St,93,German;Pubs
# La Crosse Family Restaurant,4.0,1311 La Crescent Pl,51,American (Traditional);Salad;Gastropubs
# River Rats Bar and Grill,4.5,212 Main St NE,14,American (Traditional);Seafood
# Pizza Amoré,4.0,214 Main St,66,Mexican
# The Breakfast Club and Pub,3.5,W4516 Eddie Ave,81,Bakeries;Cafes;Breakfast & Brunch
# Timmers 10 Mile Pub,4.5,1217 Caledonia St,11,Mexican
# Uptowne Cafe & Bakery,4.0,129 Marina Dr,26,Laotian;Vietnamese;Thai
# Huck Finn’s On the Water,3.0,444 N Chestnut St,39,Chicken Wings;American (Traditional);Burgers
# Schmitty’s TimeOut Tavern,5.0,1812 Jackson St,4,Sandwiches;Soup;Hot Dogs
# New Taste of India,4.0,1004 La Crosse St,96,Sandwiches;Soup
# Press Break,5.0,146 Rose St,7,American (New);Seafood;Steakhouses
# David Reay’s Modern Diner + Tavern,4.0,214 Main St,61,Breakfast & Brunch;Bars
# Rosie’s Cafe,4.5,2225 16th St S,35,American (Traditional);Cajun/Creole
# Red Pines Bar & Grill,4.5,W7305 County Rd Z,64,French;American (New)
# Hungry Peddler,4.0,3429 Mormon Coulee Rd,46,Salad;Bars;Steakhouses
# Burritos House,4.5,1205 La Crosse St,31,Music Venues;Coffee & Tea;Creperies
# Thao’s Thai Restaurant and Deli,3.5,1203 La Crosse St,18,Steakhouses;Seafood;Sandwiches
# Señor Villa,4.0,325 West Ave N,44,American (New);Pubs
# Nosh,5.0,3800 WI-16,5,American (Traditional);Irish Pub
# 4 Sisters Wine Bar and Tapas,3.5,100 Harborview Plz,93,Italian;Seafood
# La Crosse Family Restaurant,4.0,2120 Rose St,51,Seafood;Steakhouses;Desserts
# River Rats Bar and Grill,4.5,1311 La Crescent Pl,14,American (Traditional);Breakfast & Brunch;Pubs
# Pizza Amoré,4.0,212 Main St NE,66,Diners;Cafes;American (Traditional)
# The Breakfast Club and Pub,3.5,214 Main St,81,American (Traditional);Breakfast & Brunch
# Timmers 10 Mile Pub,4.5,W4516 Eddie Ave,11,Bakeries;American (Traditional);Pubs
# Uptowne Cafe & Bakery,4.0,1217 Caledonia St,26,French;Wine Bars;Cocktail Bars
# Huck Finn’s On the Water,3.0,129 Marina Dr,39,American (New);Steakhouses
# Schmitty’s TimeOut Tavern,5.0,444 N Chestnut St,4,American (Traditional);Steakhouses;Seafood
# New Taste of India,4.0,1812 Jackson St,96,Thai;Delis
# Rudy’s Drive-In,4.5,1004 La Crosse St,37,German;Pubs
# Big Mama’s Gyros,5.0,Dave's Guitar Shop Parking Lot,9,American (Traditional);Salad;Gastropubs
# Dim Sum Tea Shop,4.0,221 Pearl St,36,American (Traditional);Seafood
# North Country Steak Buffet,4.0,2526 Rose St,24,Mexican
# Kaddy’s Kafe,4.5,236 E Main St,16,Bakeries;Cafes;Breakfast & Brunch
# Ciatti’s Italian Grill,4.5,2846 Midwest Dr,39,Mexican
# Sushi Pirate,3.5,200 Main St,43,Laotian;Vietnamese;Thai
# Ye Old Style Inn,4.5,828 5th Ave S,4,Chicken Wings;American (Traditional);Burgers
# Taste of Thai,4.0,205 S Holmen Dr,25,Sandwiches;Soup;Hot Dogs
# El Rodeo Restaurant,4.0,115 5th Ave S,20,Sandwiches;Soup
# Houghton’s Jackson Street Pub,3.5,1002 Jackson St,24,Burgers;American (Traditional)
# La Crosse Family Restaurant,4.0,2120 Rose St,51,American (New);Seafood;Steakhouses
# River Rats Bar and Grill,4.5,1311 La Crescent Pl,14,Breakfast & Brunch;Bars
# Pizza Amoré,4.0,212 Main St NE,66,American (Traditional);Cajun/Creole
# The Breakfast Club and Pub,3.5,214 Main St,81,French;American (New)
# Timmers 10 Mile Pub,4.5,W4516 Eddie Ave,11,Salad;Bars;Steakhouses
# Uptowne Cafe & Bakery,4.0,1217 Caledonia St,26,Music Venues;Coffee & Tea;Creperies
# Huck Finn’s On the Water,3.0,129 Marina Dr,39,Steakhouses;Seafood;Sandwiches
# Schmitty’s TimeOut Tavern,5.0,444 N Chestnut St,4,American (New);Pubs
# New Taste of India,4.0,1812 Jackson St,96,American (Traditional);Irish Pub
# Rudy’s Drive-In,4.5,1004 La Crosse St,37,Italian;Seafood
# Big Mama’s Gyros,5.0,Dave's Guitar Shop Parking Lot,9,Seafood;Steakhouses;Desserts
# Dim Sum Tea Shop,4.0,221 Pearl St,36,American (Traditional);Breakfast & Brunch;Pubs
# North Country Steak Buffet,4.0,2526 Rose St,24,Diners;Cafes;American (Traditional)
# Kaddy’s Kafe,4.5,236 E Main St,16,American (Traditional);Breakfast & Brunch
# Ciatti’s Italian Grill,4.5,2846 Midwest Dr,39,Bakeries;American (Traditional);Pubs
# Sushi Pirate,3.5,200 Main St,43,French;Wine Bars;Cocktail Bars
# Ye Old Style Inn,4.5,828 5th Ave S,4,American (New);Steakhouses
# Taste of Thai,4.0,205 S Holmen Dr,25,American (Traditional);Steakhouses;Seafood
# El Rodeo Restaurant,4.0,115 5th Ave S,20,Thai;Delis
# Houghton’s Jackson Street Pub,3.5,1002 Jackson St,24,German;Pubs
# Three Rivers Lodge River View Restaurant and Bar,3.5,111 Front St S,22,American (Traditional);Salad;Gastropubs
# The Twisted Moose,2.5,128 3rd St S,25,American (Traditional);Seafood
# Royal Indian Cuisine,4.5,235 Sand Lake Rd,56,Mexican
# Pogreba Restaurant,3.5,1232 Avon St,36,Bakeries;Cafes;Breakfast & Brunch
# Great Harvest Bread Company,4.5,58 Copeland Ave,5,Mexican
# Schmidty’s Bar & Restaurant,4.0,3119 State Rd,15,Laotian;Vietnamese;Thai
# Fox Hollow Sports Bar,4.5,N3287 County Rd OA,10,Chicken Wings;American (Traditional);Burgers
# JavaVino,4.0,2311 State Rd,29,Sandwiches;Soup;Hot Dogs
# Great Wall,3.5,322 Main St,22,Sandwiches;Soup
# Shogun Sushi And Hibachi,4.0,1227 Crossing Meadows Dr,52,Burgers;American (Traditional)
# Big Mama’s Gyros,5.0,Dave's Guitar Shop Parking Lot,9,American (New);Seafood;Steakhouses
# Dim Sum Tea Shop,4.0,221 Pearl St,36,Breakfast & Brunch;Bars
# North Country Steak Buffet,4.0,2526 Rose St,24,American (Traditional);Cajun/Creole
# Kaddy’s Kafe,4.5,236 E Main St,16,French;American (New)
# Ciatti’s Italian Grill,4.5,2846 Midwest Dr,39,Salad;Bars;Steakhouses
# Sushi Pirate,3.5,200 Main St,43,Music Venues;Coffee & Tea;Creperies
# Ye Old Style Inn,4.5,828 5th Ave S,4,Steakhouses;Seafood;Sandwiches
# Taste of Thai,4.0,205 S Holmen Dr,25,American (New);Pubs
# El Rodeo Restaurant,4.0,115 5th Ave S,20,American (Traditional);Irish Pub
# Houghton’s Jackson Street Pub,3.5,1002 Jackson St,24,Italian;Seafood
# Three Rivers Lodge River View Restaurant and Bar,3.5,111 Front St S,22,Seafood;Steakhouses;Desserts
# The Twisted Moose,2.5,128 3rd St S,25,American (Traditional);Breakfast & Brunch;Pubs
# Royal Indian Cuisine,4.5,235 Sand Lake Rd,56,Diners;Cafes;American (Traditional)
# Pogreba Restaurant,3.5,1232 Avon St,36,American (Traditional);Breakfast & Brunch
# Great Harvest Bread Company,4.5,58 Copeland Ave,5,Bakeries;American (Traditional);Pubs
# Schmidty’s Bar & Restaurant,4.0,3119 State Rd,15,French;Wine Bars;Cocktail Bars
# Fox Hollow Sports Bar,4.5,N3287 County Rd OA,10,American (New);Steakhouses
# JavaVino,4.0,2311 State Rd,29,American (Traditional);Steakhouses;Seafood
# Great Wall,3.5,322 Main St,22,Thai;Delis
# Shogun Sushi And Hibachi,4.0,1227 Crossing Meadows Dr,52,German;Pubs
# Ardie’s Restaurant / Flipside Pub & Grill,3.5,400 Lang Dr,25,American (Traditional);Salad;Gastropubs
# Famous Dave’s,4.0,3055 State Rd 16,29,American (Traditional);Seafood
# Eagle’s Nest Sports Bar & Grill,3.5,1914 Campbell Rd,15,Mexican
# Linda’s Bakery,5.0,190 E City Hwy 16,18,Bakeries;Cafes;Breakfast & Brunch
# Marco’s Pizza,4.5,3514 Mormon Coulee Rd,7,Mexican
# Tom Sawyer’s Bar & Grill,3.5,136 Clinton St,23,Laotian;Vietnamese;Thai
# Fiesta Mexicana,4.0,5200 Mormon Coulee Rd,20,Chicken Wings;American (Traditional);Burgers
# Arterial,3.5,1003 16th St S,15,Sandwiches;Soup;Hot Dogs
# The Ridge,4.0,W2782 State Rd 33,5,Sandwiches;Soup
# Shenanigans Entertainment Center & Sports Bar,2.5,2100 Dawson Ave,13,Burgers;American (Traditional)
# Three Rivers Lodge River View Restaurant and Bar,3.5,111 Front St S,22,American (New);Seafood;Steakhouses
# The Twisted Moose,2.5,128 3rd St S,25,Breakfast & Brunch;Bars
# Royal Indian Cuisine,4.5,235 Sand Lake Rd,56,American (Traditional);Cajun/Creole
# Pogreba Restaurant,3.5,1232 Avon St,36,French;American (New)
# Great Harvest Bread Company,4.5,58 Copeland Ave,5,Salad;Bars;Steakhouses
# Schmidty’s Bar & Restaurant,4.0,3119 State Rd,15,Music Venues;Coffee & Tea;Creperies
# Fox Hollow Sports Bar,4.5,N3287 County Rd OA,10,Steakhouses;Seafood;Sandwiches
# JavaVino,4.0,2311 State Rd,29,American (New);Pubs
# Great Wall,3.5,322 Main St,22,American (Traditional);Irish Pub
# Shogun Sushi And Hibachi,4.0,1227 Crossing Meadows Dr,52,Italian;Seafood
# Ardie’s Restaurant / Flipside Pub & Grill,3.5,400 Lang Dr,25,Seafood;Steakhouses;Desserts
# Famous Dave’s,4.0,3055 State Rd 16,29,American (Traditional);Breakfast & Brunch;Pubs
# Eagle’s Nest Sports Bar & Grill,3.5,1914 Campbell Rd,15,Diners;Cafes;American (Traditional)
# Linda’s Bakery,5.0,190 E City Hwy 16,18,American (Traditional);Breakfast & Brunch
# Marco’s Pizza,4.5,3514 Mormon Coulee Rd,7,Bakeries;American (Traditional);Pubs
# Tom Sawyer’s Bar & Grill,3.5,136 Clinton St,23,French;Wine Bars;Cocktail Bars
# Fiesta Mexicana,4.0,5200 Mormon Coulee Rd,20,American (New);Steakhouses
# Arterial,3.5,1003 16th St S,15,American (Traditional);Steakhouses;Seafood
# The Ridge,4.0,W2782 State Rd 33,5,Thai;Delis
# Shenanigans Entertainment Center & Sports Bar,2.5,2100 Dawson Ave,13,German;Pubs
# Big Boar Barbecue & Catering,4.5,510 Commerce Dr,39,American (Traditional);Salad;Gastropubs
# Bean Juice,4.5,1014 19th St S,16,American (Traditional);Seafood
# El Cerrito,4.0,306 Sand Lake Rd,13,Mexican
# Nutbush City Limits,3.0,3264 George St,27,Bakeries;Cafes;Breakfast & Brunch
# Two Beagles Brewpub,3.0,910 2nd Ave N,36,Mexican
# Hackberry’s Bistro,3.5,315 5th Ave S,32,Laotian;Vietnamese;Thai
# Big Al’s Pizza,3.0,115 3rd St,51,Chicken Wings;American (Traditional);Burgers
# Culina Mariana Cafe,4.0,5250 Justin Rd,3,Sandwiches;Soup;Hot Dogs
# Pizza King-Pizza Subs Gyros,4.5,2929 S Ave,12,Sandwiches;Soup
# Angelini’s Ristorante,3.5,1427 State Hwy 35,31,Burgers;American (Traditional)
# Ardie’s Restaurant / Flipside Pub & Grill,3.5,400 Lang Dr,25,American (New);Seafood;Steakhouses
# Famous Dave’s,4.0,3055 State Rd 16,29,Breakfast & Brunch;Bars
# Eagle’s Nest Sports Bar & Grill,3.5,1914 Campbell Rd,15,American (Traditional);Cajun/Creole
# Linda’s Bakery,5.0,190 E City Hwy 16,18,French;American (New)
# Marco’s Pizza,4.5,3514 Mormon Coulee Rd,7,Salad;Bars;Steakhouses
# Tom Sawyer’s Bar & Grill,3.5,136 Clinton St,23,Music Venues;Coffee & Tea;Creperies
# Fiesta Mexicana,4.0,5200 Mormon Coulee Rd,20,Steakhouses;Seafood;Sandwiches
# Arterial,3.5,1003 16th St S,15,American (New);Pubs
# The Ridge,4.0,W2782 State Rd 33,5,American (Traditional);Irish Pub
# Shenanigans Entertainment Center & Sports Bar,2.5,2100 Dawson Ave,13,Italian;Seafood
# Big Boar Barbecue & Catering,4.5,510 Commerce Dr,39,Seafood;Steakhouses;Desserts
# Bean Juice,4.5,1014 19th St S,16,American (Traditional);Breakfast & Brunch;Pubs
# El Cerrito,4.0,306 Sand Lake Rd,13,Diners;Cafes;American (Traditional)
# Nutbush City Limits,3.0,3264 George St,27,American (Traditional);Breakfast & Brunch
# Two Beagles Brewpub,3.0,910 2nd Ave N,36,Bakeries;American (Traditional);Pubs
# Hackberry’s Bistro,3.5,315 5th Ave S,32,French;Wine Bars;Cocktail Bars
# Big Al’s Pizza,3.0,115 3rd St,51,American (New);Steakhouses
# Culina Mariana Cafe,4.0,5250 Justin Rd,3,American (Traditional);Steakhouses;Seafood
# Pizza King-Pizza Subs Gyros,4.5,2929 S Ave,12,Thai;Delis
# Angelini’s Ristorante,3.5,1427 State Hwy 35,31,German;Pubs
# Blue Moon Restaurant,3.5,716 2nd Ave N,45,American (Traditional);Salad;Gastropubs
# River Rocks Coffee,4.0,332 Front St S,4,American (Traditional);Seafood
# Pettibone Boat Club,2.5,S Pettibone Dr,34,Mexican
# Texas Roadhouse,3.5,4310 State Hwy 16,34,Bakeries;Cafes;Breakfast & Brunch
# The Verse Lounge & Grill,5.0,717 Rose St,1,Mexican
# Hunan Chinese Restaurant & Lounge,3.0,318 4th St S,20,Laotian;Vietnamese;Thai
# Rivoli Theatre & Pizzeria,4.0,117 4th St N,35,Chicken Wings;American (Traditional);Burgers
# Burger Fusion Company,2.5,200 Pearl St,18,Sandwiches;Soup;Hot Dogs
# Gracie’s Gyros & Wraps,3.0,1908 Campbell Rd,28,Sandwiches;Soup
# Sloopy’s Alma Mater,3.5,163 Copeland Ave,8,Burgers;American (Traditional)
# Big Boar Barbecue & Catering,4.5,510 Commerce Dr,39,American (New);Seafood;Steakhouses
# Bean Juice,4.5,1014 19th St S,16,Breakfast & Brunch;Bars
# El Cerrito,4.0,306 Sand Lake Rd,13,American (Traditional);Cajun/Creole
# Nutbush City Limits,3.0,3264 George St,27,French;American (New)
# Two Beagles Brewpub,3.0,910 2nd Ave N,36,Salad;Bars;Steakhouses
# Hackberry’s Bistro,3.5,315 5th Ave S,32,Music Venues;Coffee & Tea;Creperies
# Big Al’s Pizza,3.0,115 3rd St,51,Steakhouses;Seafood;Sandwiches
# Culina Mariana Cafe,4.0,5250 Justin Rd,3,American (New);Pubs
# Pizza King-Pizza Subs Gyros,4.5,2929 S Ave,12,American (Traditional);Irish Pub
# Angelini’s Ristorante,3.5,1427 State Hwy 35,31,Italian;Seafood
# Blue Moon Restaurant,3.5,716 2nd Ave N,45,Seafood;Steakhouses;Desserts
# River Rocks Coffee,4.0,332 Front St S,4,American (Traditional);Breakfast & Brunch;Pubs
# Pettibone Boat Club,2.5,S Pettibone Dr,34,Diners;Cafes;American (Traditional)
# Texas Roadhouse,3.5,4310 State Hwy 16,34,American (Traditional);Breakfast & Brunch
# The Verse Lounge & Grill,5.0,717 Rose St,1,Bakeries;American (Traditional);Pubs
# Hunan Chinese Restaurant & Lounge,3.0,318 4th St S,20,French;Wine Bars;Cocktail Bars
# Rivoli Theatre & Pizzeria,4.0,117 4th St N,35,American (New);Steakhouses
# Burger Fusion Company,2.5,200 Pearl St,18,American (Traditional);Steakhouses;Seafood
# Gracie’s Gyros & Wraps,3.0,1908 Campbell Rd,28,Thai;Delis
# Sloopy’s Alma Mater,3.5,163 Copeland Ave,8,German;Pubs
# Huhot Mongolian Grill,3.5,3039 Medco Ct,24,American (Traditional);Salad;Gastropubs
# Grizzly’s,3.0,221 Main St,38,American (Traditional);Seafood
# Lindy’s Subs & Salads,3.5,W5717 Bliss Rd,23,Mexican
# Alpine Inn,3.5,920 W City Hwy 16,17,Bakeries;Cafes;Breakfast & Brunch
# Golden China,4.5,116 3rd St S,10,Mexican
# Polito’s Pizza,3.5,621 Saint Paul St,27,Laotian;Vietnamese;Thai
# Dewey’s Side Street Saloon,3.0,133 4th St S,2,Chicken Wings;American (Traditional);Burgers
# 4 Sisters 4th Street Bar and Catering,3.5,N3287 County Trunk Oa,9,Sandwiches;Soup;Hot Dogs
# Fox Hollow Golf Course,5.0,401 Jay St,5,Sandwiches;Soup
# Blue Moon Restaurant,3.5,716 2nd Ave N,45,American (New);Seafood;Steakhouses
# River Rocks Coffee,4.0,332 Front St S,4,Breakfast & Brunch;Bars
# Pettibone Boat Club,2.5,S Pettibone Dr,34,American (Traditional);Cajun/Creole
# Texas Roadhouse,3.5,4310 State Hwy 16,34,French;American (New)
# The Verse Lounge & Grill,5.0,717 Rose St,1,Salad;Bars;Steakhouses
# Hunan Chinese Restaurant & Lounge,3.0,318 4th St S,20,Music Venues;Coffee & Tea;Creperies
# Rivoli Theatre & Pizzeria,4.0,117 4th St N,35,Steakhouses;Seafood;Sandwiches
# Burger Fusion Company,2.5,200 Pearl St,18,American (New);Pubs
# Gracie’s Gyros & Wraps,3.0,1908 Campbell Rd,28,American (Traditional);Irish Pub
# Sloopy’s Alma Mater,3.5,163 Copeland Ave,8,Italian;Seafood
# Huhot Mongolian Grill,3.5,3039 Medco Ct,24,Seafood;Steakhouses;Desserts
# Grizzly’s,3.0,221 Main St,38,American (Traditional);Breakfast & Brunch;Pubs
# Lindy’s Subs & Salads,3.5,W5717 Bliss Rd,23,Diners;Cafes;American (Traditional)
# Alpine Inn,3.5,920 W City Hwy 16,17,American (Traditional);Breakfast & Brunch
# Golden China,4.5,116 3rd St S,10,Bakeries;American (Traditional);Pubs
# Polito’s Pizza,3.5,621 Saint Paul St,27,French;Wine Bars;Cocktail Bars
# Dewey’s Side Street Saloon,3.0,133 4th St S,2,American (New);Steakhouses
# 4 Sisters 4th Street Bar and Catering,3.5,N3287 County Trunk Oa,9,American (Traditional);Steakhouses;Seafood
# Fox Hollow Golf Course,5.0,401 Jay St,5,Thai;Delis
# Cabin Coffee,4.0,24 S Walnut St,21,German;Pubs
# Quillin’s,5.0,301 Hampton Ct,1,American (Traditional);Salad;Gastropubs
# Manny’s Mexican Cocina,3.5,2005 West Ave S,87,American (Traditional);Seafood
# The Barrel Bar & Grill,4.0,807 4th St S,5,Mexican
# Pla-Mor Lanes and The Eleventh Frame Diner,5.0,1123 3rd St S,6,Bakeries;Cafes;Breakfast & Brunch
# Kramer’s Bar & Grill,4.0,127 S 3rd St,6,Mexican
# QDOBA Mexican Eats,3.5,2843 Darling Ct,14,Laotian;Vietnamese;Thai
# Cabin Coffee La Crosse North,5.0,40 Copeland Ave,2,Chicken Wings;American (Traditional);Burgers
# B.A. Burrito Co.,3.0,205 Main St,25,Sandwiches;Soup;Hot Dogs
# Maggie’s On Main,3.0,1835 Rose St,16,Sandwiches;Soup
